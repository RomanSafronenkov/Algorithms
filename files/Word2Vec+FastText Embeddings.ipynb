# %% [markdown]
# # Word2Vec + FastText

# %%
import collections
import copy
import re
from itertools import product
import traceback

import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
full_dataset = list(pd.read_csv('./data/nyt-ingredients-snapshot-2015.csv')['input'].dropna())
np.random.shuffle(full_dataset)

print("Размер выборки", len(full_dataset))

print('\n'.join(full_dataset[:10]))
# Out:
# Размер выборки 179063
# 1 cup plus a splash orange liqueur
# 1/2 cup beer
# 1 pound potatoes, preferably fingerling, Ruby Crescent or Yellow Finn
# 1 branch fresh tarragon or thyme separated into sprigs, or 1/2 teaspoon dried thyme or tarragon
# 3 pints boiling water
# 1/2 cup plus 1 tablespoon extra-virgin olive oil
# 1/2 cup flour
# 1/4 teaspoon salt, plus more to taste
# 1 medium yellow squash, cut into small dice
# 2 teaspoons rice vinegar

# %%
TOKEN_RE = re.compile(r'[\w\d]+')


def tokenize_text_simple_regex(txt, min_token_size=4):
    txt = txt.lower()
    all_tokens = TOKEN_RE.findall(txt)
    return [token for token in all_tokens if len(token) >= min_token_size]

def tokenize_corpus(texts, tokenizer=tokenize_text_simple_regex, **tokenizer_kwargs):
    return [tokenizer(text, **tokenizer_kwargs) for text in texts]

def build_vocabulary(tokenized_texts, max_size=1000000, max_doc_freq=0.8, min_count=5, pad_word=None):
    word_counts = collections.defaultdict(int)
    doc_n = 0

    # посчитать количество документов, в которых употребляется каждое слово
    # а также общее количество документов
    for txt in tokenized_texts:
        doc_n += 1
        unique_text_tokens = set(txt)
        for token in unique_text_tokens:
            word_counts[token] += 1

    # убрать слишком редкие и слишком частые слова
    word_counts = {word: cnt for word, cnt in word_counts.items()
                   if cnt >= min_count and cnt / doc_n <= max_doc_freq}

    # отсортировать слова по убыванию частоты
    sorted_word_counts = sorted(word_counts.items(),
                                reverse=True,
                                key=lambda pair: pair[1])

    # добавим несуществующее слово с индексом 0 для удобства пакетной обработки
    if pad_word is not None:
        sorted_word_counts = [(pad_word, 0)] + sorted_word_counts

    # если у нас по прежнему слишком много слов, оставить только max_size самых частотных
    if len(word_counts) > max_size:
        sorted_word_counts = sorted_word_counts[:max_size]

    # нумеруем слова
    word2id = {word: i for i, (word, _) in enumerate(sorted_word_counts)}

    # нормируем частоты слов
    word2freq = np.array([cnt / doc_n for _, cnt in sorted_word_counts], dtype='float32')

    return word2id, word2freq

def texts_to_token_ids(tokenized_texts, word2id):
    return [[word2id[token] for token in text if token in word2id]
            for text in tokenized_texts]

# %%
tokenized_texts = tokenize_corpus(full_dataset)
word2id, word2freq = build_vocabulary(tokenized_texts, max_doc_freq=0.9, min_count=5, pad_word='<PAD>')

token_ids = texts_to_token_ids(tokenized_texts, word2id)

print('\n'.join(' '.join(str(t) for t in sent)
                for sent in token_ids[:10]))
# Out:
# 45 872 97 411
# 596
# 12 92 79 1095 1020 150 1981
# 1270 9 206 63 244 29 82 2 41 63 206
# 603 371 39
# 45 8 40 44 13
# 38
# 2 4 45 47 10
# 35 150 233 29 36 171
# 17 72 48

# %%
class SequenceDataset:
    def __init__(self, texts, pad_value=0):
        self.texts = texts
        self.pad_value = pad_value

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, item):
        txt = self.texts[item]

        txt = np.array(txt)

        return txt

# %%
dataset = SequenceDataset(token_ids)

print(dataset[0])
# Out:
# [ 45 872  97 411]

# %%
def make_diag_mask(size, radius):
    """Квадратная матрица размера Size x Size с двумя полосами ширины radius вдоль главной диагонали"""
    idxs = np.arange(size)
    abs_idx_diff = np.abs(np.arange(size)[np.newaxis, :] - np.arange(size)[:, np.newaxis])
    mask = ((abs_idx_diff <= radius // 2) & (abs_idx_diff > 0)).astype(int)
    return mask

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def sigmoid_derivative(z):
    s = 1 / (1 + np.exp(-z))
    return s * (1 - s)

def log_loss(y_true, a_pred):
    '''
    Compute log loss, a_pred - vector of size n_objects
    '''
    return np.mean(-y_true * np.log(a_pred) - (1 - y_true) * np.log(1 - a_pred))

def log_loss_derivative(y_true, a_pred):
    '''
    Compute detivative of log loss
    '''
    return (-y_true / a_pred + (1 - y_true) / (1 - a_pred)) / len(y_true)

# %%
class Word2VecVanilla:
    def __init__(self, vocabulary, emb_size, window_size, ns_rate, pad_idx=0):
        self.vocabulary = vocabulary
        self.vocab_size = len(vocabulary)
        self.emb_size = emb_size
        self.window_size = window_size
        self.ns_rate = ns_rate
        self.pad_idx = pad_idx
        
        self.center_embeddings = np.random.uniform(-1.0/self.emb_size, 1.0/self.emb_size,
                                                   size=(self.vocab_size, self.emb_size))
        self.center_embeddings[pad_idx] = 0
        
        self.context_embeddings = np.random.uniform(-1.0/self.emb_size, 1.0/self.emb_size,
                                                    size=(self.vocab_size, self.emb_size))
        self.context_embeddings[pad_idx] = 0
        
        self.id2word = {i: w for w, i in self.vocabulary.items()}
        
        self.embeddings_normed = None
        
    
    def norm_embeddings(self):
        self.embeddings_normed = self.center_embeddings / (np.linalg.norm(
            self.center_embeddings, ord=2, axis=-1, keepdims=True) + 1e-4)

    def generate_w2v_sgns_samples(self, text):
        """
        text - list of integer numbers - ids of tokens in text
        window_size - odd integer - width of window
        vocab_size - positive integer - number of tokens in vocabulary
        ns_rate - positive integer - number of negative tokens to sample per one positive sample

        returns list of training samples (CenterWord, CtxWord, Label)
        """
        text = np.array(text)
        size = len(text)
        context_words_idxs = make_diag_mask(size, self.window_size)
        center_words_idx = np.eye(N=size, dtype=int)

        result = []

        for i in range(size):
            context = context_words_idxs[i]
            center = center_words_idx[i]

            context_idx = np.where(context != 0)[0]
            center_idx = np.where(center != 0)[0]

            center_word = text[center_idx]
            context_words = text[context_idx]

            if center_word == self.pad_idx:
                continue

            positive_examples = [list(i) + [1] for i in product(center_word, context_words)]
            positive_examples = [
                positive_example for positive_example in positive_examples if self.pad_idx not in positive_example
            ]

            # чтобы не совпадало с самим собой
            all_words = np.arange(self.vocab_size)
            center_word_idx = np.argwhere(all_words == center_word)[0][0]
            all_words = list(all_words)
            del all_words[center_word_idx], all_words[self.pad_idx]
            all_words = np.array(all_words)
            negative_word = np.random.choice(all_words)

            # выбрать одно из двух, либо убрать совпадение с самим собой, либо нет
            negative_words = np.random.randint(self.vocab_size, size=self.ns_rate*len(positive_examples))    
            negative_examples = [list(i) + [0] for i in product(center_word, negative_words)]

            positive_negative_examples = positive_examples + negative_examples    
            result.extend(positive_negative_examples)

        return np.random.permutation(result)
    

    def update_w2v_weights(self, center_word, context_word, label, learning_rate):
        """
        center_embeddings - VocabSize x EmbSize
        context_embeddings - VocabSize x EmbSize
        center_word - int - identifier of center word
        context_word - int - identifier of context word
        label - 1 if context_word is real, 0 if it is negative
        learning_rate - float > 0 - size of gradient step
        """

        # Выберем центральное и контекстное слово
        center_embedding = self.center_embeddings[center_word]
        context_embedding = self.context_embeddings[context_word]

        # Считаем "оценку" сходства и ее вероятность по формуле 𝑃(𝐶𝑡𝑥𝑊𝑜𝑟𝑑|𝐶𝑒𝑛𝑡𝑒𝑟𝑊𝑜𝑟𝑑)=𝜎(𝑊𝐶𝑒𝑛𝑡𝑒𝑟𝑊𝑜𝑟𝑑,:⋅𝐷𝐶𝑡𝑥𝑊𝑜𝑟𝑑,:)
        score = center_embedding.dot(context_embedding)
        prob = sigmoid(score)

        loss = log_loss(label, prob)

        # Считаем производные для правила цепочки: производная лосса * производную сигмоиды
        # * производную 𝑊𝐶𝑒𝑛𝑡𝑒𝑟𝑊𝑜𝑟𝑑,:⋅𝐷𝐶𝑡𝑥𝑊𝑜𝑟𝑑,: по 𝑊𝐶𝑒𝑛𝑡𝑒𝑟𝑊𝑜𝑟𝑑 и 𝐷𝐶𝑡𝑥𝑊𝑜𝑟𝑑
        log_loss_deriv = log_loss_derivative(np.array([label]), np.array([prob]))
        sigmoid_deriv = sigmoid_derivative(score)

        # Считаем производные по цетральному слову и контекстному для обновления весов
        center_grad = log_loss_deriv * sigmoid_deriv * context_embedding
        context_grad = log_loss_deriv * sigmoid_deriv * center_embedding

        self.center_embeddings[center_word] -= learning_rate * center_grad
        self.context_embeddings[context_word] -= learning_rate * context_grad

        return loss
    
    def fit(self, dataset, learning_rate=1e-2, n_epochs=10):
        for n in tqdm(range(n_epochs)):
            try:
                idxs = np.random.permutation(len(dataset))

                for i, idx in enumerate(idxs):
                    data = dataset[idx]
                    samples = self.generate_w2v_sgns_samples(text=data)

                    cur_idx = 1
                    cur_loss = 0

                    for sample in samples:
                        center_word, context_word, label = sample

                        loss = self.update_w2v_weights(
                            center_word=center_word,
                            context_word=context_word,
                            label=label,
                            learning_rate=learning_rate
                        )

                        cur_loss += loss
                        cur_idx += 1

                print(f"LOSS: {cur_loss / cur_idx}")

            except KeyboardInterrupt:
                print('Досрочно остановлено пользователем')
                return self

            except Exception as ex:
                print('Ошибка при обучении: {}\n{}'.format(ex, traceback.format_exc()))
                break
        return self
    
    def most_similar(self, word, topk=10):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        return self.most_similar_by_vector(self.get_vector(word), topk=topk)

    def analogy(self, a1, b1, a2, topk=10):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        a1_v = self.get_vector(a1)
        b1_v = self.get_vector(b1)
        a2_v = self.get_vector(a2)
        query = b1_v - a1_v + a2_v
        return self.most_similar_by_vector(query, topk=topk)

    def most_similar_by_vector(self, query_vector, topk=10):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        similarities = (self.embeddings_normed * query_vector).sum(-1)
        best_indices = np.argpartition(-similarities, topk, axis=0)[:topk]
        result = [(self.id2word[i], similarities[i]) for i in best_indices]
        result.sort(key=lambda pair: -pair[1])
        return result

    def get_vector(self, word):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        if word not in self.vocabulary:
            raise ValueError('Неизвестное слово "{}"'.format(word))
        return self.embeddings_normed[self.vocabulary[word]]

    def get_vectors(self, *words):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        word_ids = [self.vocabulary[i] for i in words]
        vectors = np.stack([self.embeddings_normed[i] for i in word_ids], axis=0)
        return vectors

# %%
word2vec = Word2VecVanilla(
    vocabulary=word2id,
    emb_size=100,
    window_size=5,
    ns_rate=10,
    pad_idx=0
)

# %%
word2vec.fit(dataset, n_epochs=3)
# Out:
#  33%|███████████████████████████▋                                                       | 1/3 [12:46<25:32, 766.44s/it]
# LOSS: 0.027821838962048352
#  67%|███████████████████████████████████████████████████████▎                           | 2/3 [25:30<12:45, 765.12s/it]
# LOSS: 0.11800157154489815
# 100%|███████████████████████████████████████████████████████████████████████████████████| 3/3 [38:12<00:00, 764.21s/it]
# LOSS: 0.0

# %%
word2vec.norm_embeddings()
print('chicken\n', word2vec.most_similar('chicken'), '\n')
print('wine\n', word2vec.most_similar('wine'), '\n')
print('salt\n', word2vec.most_similar('salt'), '\n')
# Out:
# chicken
#  [('chicken', 0.9999628414370786), ('duck', 0.8375601140226202), ('turkey', 0.8134993126393183), ('thighs', 0.7932530122474649), ('legs', 0.7838325180714862), ('breasts', 0.7802486438501787), ('breast', 0.7801002868214305), ('wings', 0.753420181955752), ('drumsticks', 0.7485258358195042), ('veal', 0.7318013286752812)]
#
# wine
#  [('wine', 0.9999613666041658), ('sherry', 0.8561270823775503), ('grigio', 0.8388384086243729), ('sauvignon', 0.8283005488345155), ('champagne', 0.8236668280750943), ('balsamic', 0.8190846118740012), ('shao', 0.8018726020419095), ('pinot', 0.7912309005701603), ('bottle', 0.7877572708844414), ('hsing', 0.7865292393456697)]
#
# salt
#  [('salt', 0.9999665549606125), ('fleur', 0.8062762320131163), ('kosher', 0.7799918669723506), ('nblack', 0.7522017818029882), ('cayenne', 0.7462796715024314), ('diamond', 0.7399968981457564), ('maldon', 0.7319423615480875), ('lots', 0.7245726593757553), ('passover', 0.71830744908613), ('asafetida', 0.7182918669222995)]

# %%
def get_n_gramms(word, n):
    size = len(word) - n + 1
    return [word[i:i+n] for i in range(size)]

def make_ngramms_dict(vocabulary, n_list):
    max_num = max(vocabulary.values())+1
    ngramms = []
    
    for word in vocabulary.keys():
        for n in n_list:
            gramms = get_n_gramms(word, n)
            ngramms.extend(gramms)
            
    ngramms = set(ngramms)
    ngramm2id = {ngramm:i+max_num for i, ngramm in enumerate(ngramms)}
    return ngramm2id

def make_token2subwords(words_voc, ngramm_voc, n_list):
    token2subwords = {}
    
    for word in words_voc.keys():
        
        gramms_ids = []
        for n in n_list:
            for gramm in get_n_gramms(word, n):
                gramms_ids.append(ngramm_voc[gramm])
                
        token2subwords[words_voc[word]] = gramms_ids
    return token2subwords

# %%
n_list = [2]

ngramm2id = make_ngramms_dict(word2id, n_list=n_list)
ngramm2id
# Out:
# {'ab': 2632,
#  'bl': 2633,
#  '27': 2634,
#  'pc': 2635,
#  'on': 2636,
#  'dj': 2637,
#  'lc': 2638,
#  'zo': 2639,
#  'ua': 2640,
#  'fl': 2641,
#  'ax': 2642,
#  'de': 2643,
#  'nn': 2644,
#  'ue': 2645,
#  'ay': 2646,
#  'kk': 2647,
#  'ld': 2648,
#  'od': 2649,
#  'zc': 2650,
#  'bb': 2651,
#  'ku': 2652,
#  'oc': 2653,
#  'rè': 2654,
#  'af': 2655,
#  'te': 2656,
#  'ag': 2657,
#  'va': 2658,
#  'ex': 2659,
#  'wo': 2660,
#  'mt': 2661,
#  'ib': 2662,
#  'ff': 2663,
#  'ca': 2664,
#  'îc': 2665,
#  '17': 2666,
#  'by': 2667,
#  'ém': 2668,
#  'ev': 2669,
#  'kp': 2670,
#  'oe': 2671,
#  'zz': 2672,
#  'yè': 2673,
#  'ik': 2674,
#  'ow': 2675,
#  '05': 2676,
#  'un': 2677,
#  'ón': 2678,
#  'oy': 2679,
#  'pr': 2680,
#  'ks': 2681,
#  'gt': 2682,
#  'mi': 2683,
#  'sm': 2684,
#  'it': 2685,
#  'ws': 2686,
#  'ch': 2687,
#  'dc': 2688,
#  'sc': 2689,
#  '64': 2690,
#  '41': 2691,
#  'hl': 2692,
#  'ud': 2693,
#  'do': 2694,
#  'ph': 2695,
#  'ze': 2696,
#  'sh': 2697,
#  'ge': 2698,
#  'mo': 2699,
#  'lp': 2700,
#  'ei': 2701,
#  'ôn': 2702,
#  'si': 2703,
#  'su': 2704,
#  'da': 2705,
#  'tp': 2706,
#  '56': 2707,
#  'xs': 2708,
#  'pt': 2709,
#  'uc': 2710,
#  'èm': 2711,
#  'ri': 2712,
#  'ye': 2713,
#  'rp': 2714,
#  'kn': 2715,
#  'lr': 2716,
#  'wt': 2717,
#  'oi': 2718,
#  'mc': 2719,
#  'rd': 2720,
#  'añ': 2721,
#  'rz': 2722,
#  'gi': 2723,
#  'lt': 2724,
#  'ip': 2725,
#  'rm': 2726,
#  'lb': 2727,
#  'vr': 2728,
#  'ia': 2729,
#  'dy': 2730,
#  'ug': 2731,
#  'ym': 2732,
#  'eñ': 2733,
#  'cy': 2734,
#  'gp': 2735,
#  'gy': 2736,
#  '10': 2737,
#  'rf': 2738,
#  'sn': 2739,
#  'né': 2740,
#  'ur': 2741,
#  'én': 2742,
#  'âc': 2743,
#  'ru': 2744,
#  'oo': 2745,
#  'aj': 2746,
#  'il': 2747,
#  'my': 2748,
#  'up': 2749,
#  'nr': 2750,
#  'oz': 2751,
#  'nb': 2752,
#  'fs': 2753,
#  'kt': 2754,
#  'wr': 2755,
#  'ps': 2756,
#  'lf': 2757,
#  'ky': 2758,
#  'AD': 2759,
#  'am': 2760,
#  'vi': 2761,
#  'nu': 2762,
#  'sp': 2763,
#  '42': 2764,
#  'ir': 2765,
#  'eo': 2766,
#  'hi': 2767,
#  'xi': 2768,
#  '66': 2769,
#  'ya': 2770,
#  'ol': 2771,
#  'ti': 2772,
#  'ft': 2773,
#  'dn': 2774,
#  'rw': 2775,
#  'ct': 2776,
#  'ak': 2777,
#  'ys': 2778,
#  'ma': 2779,
#  'ço': 2780,
#  '60': 2781,
#  'tl': 2782,
#  'ea': 2783,
#  'sy': 2784,
#  'gr': 2785,
#  'eh': 2786,
#  'ds': 2787,
#  'pi': 2788,
#  'ad': 2789,
#  'ej': 2790,
#  'uz': 2791,
#  '26': 2792,
#  'bs': 2793,
#  'yt': 2794,
#  'se': 2795,
#  'PA': 2796,
#  'jo': 2797,
#  'aq': 2798,
#  'gu': 2799,
#  'hs': 2800,
#  'ôt': 2801,
#  'bm': 2802,
#  'df': 2803,
#  'rv': 2804,
#  'pk': 2805,
#  'tf': 2806,
#  'xa': 2807,
#  'ep': 2808,
#  'el': 2809,
#  'lu': 2810,
#  'lk': 2811,
#  'rh': 2812,
#  'ut': 2813,
#  'ce': 2814,
#  'br': 2815,
#  'nf': 2816,
#  'rt': 2817,
#  'gm': 2818,
#  'im': 2819,
#  'kw': 2820,
#  'ae': 2821,
#  'uu': 2822,
#  'nj': 2823,
#  'yc': 2824,
#  'ek': 2825,
#  'gh': 2826,
#  'ef': 2827,
#  'pu': 2828,
#  'ml': 2829,
#  'ne': 2830,
#  'ls': 2831,
#  'bh': 2832,
#  'je': 2833,
#  'om': 2834,
#  'ie': 2835,
#  'iu': 2836,
#  'èr': 2837,
#  'yi': 2838,
#  'es': 2839,
#  'is': 2840,
#  'in': 2841,
#  'bu': 2842,
#  'pe': 2843,
#  'la': 2844,
#  'ap': 2845,
#  'ly': 2846,
#  'of': 2847,
#  'tn': 2848,
#  'dv': 2849,
#  'wf': 2850,
#  'ho': 2851,
#  'or': 2852,
#  'ot': 2853,
#  'aw': 2854,
#  'em': 2855,
#  'tb': 2856,
#  'ic': 2857,
#  'sé': 2858,
#  'bi': 2859,
#  'zt': 2860,
#  'nd': 2861,
#  'lv': 2862,
#  'iw': 2863,
#  'mâ': 2864,
#  '_b': 2865,
#  'dk': 2866,
#  'oh': 2867,
#  'rn': 2868,
#  'bo': 2869,
#  'we': 2870,
#  'ig': 2871,
#  '43': 2872,
#  'aî': 2873,
#  'um': 2874,
#  'té': 2875,
#  'ah': 2876,
#  'ñe': 2877,
#  'ci': 2878,
#  'os': 2879,
#  'za': 2880,
#  '01': 2881,
#  'gn': 2882,
#  'if': 2883,
#  'yo': 2884,
#  'yu': 2885,
#  'rg': 2886,
#  'ki': 2887,
#  'ob': 2888,
#  'ew': 2889,
#  'rs': 2890,
#  'kb': 2891,
#  'nv': 2892,
#  'ée': 2893,
#  'st': 2894,
#  'hô': 2895,
#  'ez': 2896,
#  'ry': 2897,
#  'ar': 2898,
#  'ee': 2899,
#  '69': 2900,
#  '46': 2901,
#  'rj': 2902,
#  'ck': 2903,
#  'tu': 2904,
#  'ré': 2905,
#  'nc': 2906,
#  'an': 2907,
#  'tc': 2908,
#  'he': 2909,
#  'wi': 2910,
#  'ár': 2911,
#  '<P': 2912,
#  'ba': 2913,
#  'ty': 2914,
#  'nh': 2915,
#  'xe': 2916,
#  'yl': 2917,
#  'tr': 2918,
#  'ke': 2919,
#  'me': 2920,
#  'yd': 2921,
#  'cu': 2922,
#  'ño': 2923,
#  'dt': 2924,
#  '25': 2925,
#  '71': 2926,
#  'sr': 2927,
#  'lo': 2928,
#  'rb': 2929,
#  'nl': 2930,
#  'pa': 2931,
#  'iv': 2932,
#  'cn': 2933,
#  'hu': 2934,
#  'gg': 2935,
#  'sl': 2936,
#  'rc': 2937,
#  'fi': 2938,
#  'az': 2939,
#  'ux': 2940,
#  'op': 2941,
#  'di': 2942,
#  'ja': 2943,
#  'ix': 2944,
#  'rr': 2945,
#  'wh': 2946,
#  'ey': 2947,
#  '73': 2948,
#  'ta': 2949,
#  'iq': 2950,
#  'io': 2951,
#  'dr': 2952,
#  'ai': 2953,
#  'mq': 2954,
#  'yp': 2955,
#  'eq': 2956,
#  'wl': 2957,
#  'wn': 2958,
#  'gl': 2959,
#  'yb': 2960,
#  've': 2961,
#  'en': 2962,
#  'ju': 2963,
#  'hr': 2964,
#  'tw': 2965,
#  'og': 2966,
#  'le': 2967,
#  'xt': 2968,
#  'so': 2969,
#  'mu': 2970,
#  'co': 2971,
#  'hm': 2972,
#  'tt': 2973,
#  'ui': 2974,
#  'np': 2975,
#  'nt': 2976,
#  'ac': 2977,
#  'yf': 2978,
#  'ça': 2979,
#  'et': 2980,
#  'db': 2981,
#  'mb': 2982,
#  'go': 2983,
#  '20': 2984,
#  '72': 2985,
#  'pb': 2986,
#  'ov': 2987,
#  'ns': 2988,
#  'uf': 2989,
#  'ny': 2990,
#  'ra': 2991,
#  'th': 2992,
#  'ln': 2993,
#  'hf': 2994,
#  'kl': 2995,
#  '44': 2996,
#  'wb': 2997,
#  'ts': 2998,
#  'sk': 2999,
#  'as': 3000,
#  'oa': 3001,
#  'uv': 3002,
#  'eg': 3003,
#  'eu': 3004,
#  'cl': 3005,
#  'er': 3006,
#  'vo': 3007,
#  'fe': 3008,
#  'ox': 3009,
#  'zl': 3010,
#  'fu': 3011,
#  'na': 3012,
#  'oq': 3013,
#  'ha': 3014,
#  'ko': 3015,
#  'uo': 3016,
#  'ul': 3017,
#  '76': 3018,
#  'hw': 3019,
#  'li': 3020,
#  're': 3021,
#  'ec': 3022,
#  'kf': 3023,
#  'al': 3024,
#  'fy': 3025,
#  'gs': 3026,
#  'ed': 3027,
#  'rl': 3028,
#  'iç': 3029,
#  '14': 3030,
#  'to': 3031,
#  'yr': 3032,
#  'll': 3033,
#  'éd': 3034,
#  'ro': 3035,
#  'nk': 3036,
#  'pl': 3037,
#  'lg': 3038,
#  'ht': 3039,
#  'av': 3040,
#  'wa': 3041,
#  'cc': 3042,
#  'iz': 3043,
#  'xc': 3044,
#  'ka': 3045,
#  'uk': 3046,
#  'wu': 3047,
#  'kr': 3048,
#  'ok': 3049,
#  'ng': 3050,
#  'dd': 3051,
#  'sw': 3052,
#  'ii': 3053,
#  'hy': 3054,
#  'ij': 3055,
#  'ub': 3056,
#  'ji': 3057,
#  'yn': 3058,
#  'eb': 3059,
#  'dg': 3060,
#  'po': 3061,
#  'mp': 3062,
#  'cr': 3063,
#  'tz': 3064,
#  'uy': 3065,
#  'xy': 3066,
#  'py': 3067,
#  'nz': 3068,
#  'mg': 3069,
#  'us': 3070,
#  'au': 3071,
#  'ss': 3072,
#  'ni': 3073,
#  'cô': 3074,
#  'id': 3075,
#  'fa': 3076,
#  'dw': 3077,
#  'vy': 3078,
#  'uq': 3079,
#  'ga': 3080,
#  'D>': 3081,
#  'nm': 3082,
#  'mm': 3083,
#  'sq': 3084,
#  'zi': 3085,
#  'ms': 3086,
#  'wd': 3087,
#  'bé': 3088,
#  'no': 3089,
#  'pp': 3090,
#  'sa': 3091,
#  'dl': 3092,
#  'aç': 3093,
#  'tm': 3094,
#  'be': 3095,
#  'lm': 3096,
#  'zu': 3097,
#  'ao': 3098,
#  'at': 3099,
#  'ou': 3100,
#  'rk': 3101,
#  'du': 3102,
#  '96': 3103,
#  'aa': 3104,
#  'hn': 3105,
#  'uj': 3106,
#  'qu': 3107,
#  'tó': 3108,
#  'fr': 3109,
#  'fo': 3110}

# %%
word2id
# Out:
# {'<PAD>': 0,
#  'tablespoons': 1,
#  'teaspoon': 2,
#  'chopped': 3,
#  'salt': 4,
#  'pepper': 5,
#  'cups': 6,
#  'ground': 7,
#  'tablespoon': 8,
#  'fresh': 9,
#  'taste': 10,
#  'freshly': 11,
#  'pound': 12,
#  'olive': 13,
#  'garlic': 14,
#  'peeled': 15,
#  'finely': 16,
#  'teaspoons': 17,
#  'large': 18,
#  'minced': 19,
#  'butter': 20,
#  'ounces': 21,
#  'black': 22,
#  'sugar': 23,
#  'about': 24,
#  'pounds': 25,
#  'juice': 26,
#  'sliced': 27,
#  'white': 28,
#  'into': 29,
#  'inch': 30,
#  'lemon': 31,
#  'cloves': 32,
#  'leaves': 33,
#  'onion': 34,
#  'medium': 35,
#  'small': 36,
#  'grated': 37,
#  'flour': 38,
#  'water': 39,
#  'extra': 40,
#  'dried': 41,
#  'parsley': 42,
#  'wine': 43,
#  'virgin': 44,
#  'plus': 45,
#  'chicken': 46,
#  'more': 47,
#  'vinegar': 48,
#  'diced': 49,
#  'unsalted': 50,
#  'cream': 51,
#  'ounce': 52,
#  'optional': 53,
#  'whole': 54,
#  'sauce': 55,
#  'tomatoes': 56,
#  'kosher': 57,
#  'green': 58,
#  'eggs': 59,
#  'milk': 60,
#  'grams': 61,
#  'vegetable': 62,
#  'thyme': 63,
#  'cheese': 64,
#  'thinly': 65,
#  'coarsely': 66,
#  'pieces': 67,
#  'ginger': 68,
#  'garnish': 69,
#  'seeds': 70,
#  'powder': 71,
#  'rice': 72,
#  'seeded': 73,
#  'slices': 74,
#  'trimmed': 75,
#  'heavy': 76,
#  'clove': 77,
#  'stock': 78,
#  'preferably': 79,
#  'with': 80,
#  'pinch': 81,
#  'sprigs': 82,
#  'bread': 83,
#  'onions': 84,
#  'leaf': 85,
#  'baking': 86,
#  'purpose': 87,
#  'ripe': 88,
#  'desired': 89,
#  'basil': 90,
#  'celery': 91,
#  'potatoes': 92,
#  'mustard': 93,
#  'lime': 94,
#  'scallions': 95,
#  'thin': 96,
#  'orange': 97,
#  'thick': 98,
#  'vanilla': 99,
#  'corn': 100,
#  'broth': 101,
#  'cooked': 102,
#  'removed': 103,
#  'cilantro': 104,
#  'cinnamon': 105,
#  'crushed': 106,
#  'canned': 107,
#  'drained': 108,
#  'half': 109,
#  'sweet': 110,
#  'brown': 111,
#  'toasted': 112,
#  'recipe': 113,
#  'mushrooms': 114,
#  'parmesan': 115,
#  'coarse': 116,
#  'cumin': 117,
#  'halved': 118,
#  'tomato': 119,
#  'carrots': 120,
#  'each': 121,
#  'size': 122,
#  'shallots': 123,
#  'cooking': 124,
#  'cored': 125,
#  'mint': 126,
#  'zest': 127,
#  'other': 128,
#  'fine': 129,
#  'coriander': 130,
#  'needed': 131,
#  'serving': 132,
#  'lightly': 133,
#  'rinsed': 134,
#  'cubes': 135,
#  'flakes': 136,
#  'peanut': 137,
#  'beans': 138,
#  'bunch': 139,
#  'note': 140,
#  'cayenne': 141,
#  'from': 142,
#  'italian': 143,
#  'chili': 144,
#  'like': 145,
#  'http': 146,
#  'href': 147,
#  'recipes': 148,
#  'nytimes': 149,
#  'yellow': 150,
#  'extract': 151,
#  'light': 152,
#  'packed': 153,
#  'peppers': 154,
#  'sesame': 155,
#  'paste': 156,
#  'sherry': 157,
#  'nutmeg': 158,
#  'washed': 159,
#  'rosemary': 160,
#  'beaten': 161,
#  'quartered': 162,
#  'boneless': 163,
#  'chives': 164,
#  'dijon': 165,
#  'beef': 166,
#  'bell': 167,
#  'yogurt': 168,
#  'dark': 169,
#  'honey': 170,
#  'dice': 171,
#  'pork': 172,
#  'room': 173,
#  'temperature': 174,
#  'fillets': 175,
#  'roughly': 176,
#  'crumbs': 177,
#  'canola': 178,
#  'pitted': 179,
#  'fish': 180,
#  'cold': 181,
#  'very': 182,
#  'shredded': 183,
#  'stems': 184,
#  'lengthwise': 185,
#  'melted': 186,
#  'peppercorns': 187,
#  'cleaned': 188,
#  'shrimp': 189,
#  'frozen': 190,
#  'fennel': 191,
#  'strips': 192,
#  'stemmed': 193,
#  'syrup': 194,
#  'such': 195,
#  'approximately': 196,
#  'stick': 197,
#  'head': 198,
#  'yolks': 199,
#  'flat': 200,
#  'chunks': 201,
#  'paprika': 202,
#  'oregano': 203,
#  'bacon': 204,
#  'plain': 205,
#  'tarragon': 206,
#  'dill': 207,
#  'almonds': 208,
#  'well': 209,
#  'chocolate': 210,
#  'plum': 211,
#  'crumbled': 212,
#  'granulated': 213,
#  'long': 214,
#  'roasted': 215,
#  'soda': 216,
#  'carrot': 217,
#  'squeezed': 218,
#  'lamb': 219,
#  'wedges': 220,
#  'wheat': 221,
#  'olives': 222,
#  'sage': 223,
#  'skinless': 224,
#  'apple': 225,
#  'sour': 226,
#  'spinach': 227,
#  'homemade': 228,
#  'peas': 229,
#  'shelled': 230,
#  'cider': 231,
#  'cornstarch': 232,
#  'squash': 233,
#  'baby': 234,
#  'piece': 235,
#  'balsamic': 236,
#  'smoked': 237,
#  'only': 238,
#  'zucchini': 239,
#  'walnuts': 240,
#  'stalks': 241,
#  'slivered': 242,
#  'raisins': 243,
#  'separated': 244,
#  'coconut': 245,
#  'greasing': 246,
#  'lettuce': 247,
#  'firm': 248,
#  'leeks': 249,
#  'apples': 250,
#  'capers': 251,
#  'greens': 252,
#  'grain': 253,
#  'cabbage': 254,
#  'bean': 255,
#  'salmon': 256,
#  'frying': 257,
#  'shallot': 258,
#  'sticks': 259,
#  'meat': 260,
#  'mixed': 261,
#  'soaked': 262,
#  'nuts': 263,
#  'available': 264,
#  'confectioners': 265,
#  'turkey': 266,
#  'softened': 267,
#  'veal': 268,
#  'rind': 269,
#  'inches': 270,
#  'unsweetened': 271,
#  'buttermilk': 272,
#  'sodium': 273,
#  'style': 274,
#  'parts': 275,
#  'good': 276,
#  'sprig': 277,
#  'part': 278,
#  'skin': 279,
#  'allspice': 280,
#  'quarts': 281,
#  'lean': 282,
#  'cornmeal': 283,
#  'mayonnaise': 284,
#  'lemons': 285,
#  'seed': 286,
#  'whites': 287,
#  'chile': 288,
#  'chilies': 289,
#  'additional': 290,
#  'skinned': 291,
#  'jalapeno': 292,
#  'smashed': 293,
#  'pasta': 294,
#  'pint': 295,
#  'breasts': 296,
#  'ribs': 297,
#  'yeast': 298,
#  'chinese': 299,
#  'peel': 300,
#  'turmeric': 301,
#  'split': 302,
#  'deveined': 303,
#  'curry': 304,
#  'arugula': 305,
#  'anchovy': 306,
#  'wild': 307,
#  'cucumber': 308,
#  'scrubbed': 309,
#  'blanched': 310,
#  'chilled': 311,
#  'soft': 312,
#  'shiitake': 313,
#  'pine': 314,
#  'yolk': 315,
#  'torn': 316,
#  'package': 317,
#  'quart': 318,
#  'broccoli': 319,
#  'serrano': 320,
#  'bunches': 321,
#  'jalapeño': 322,
#  'noodles': 323,
#  'heads': 324,
#  'cherry': 325,
#  'pumpkin': 326,
#  'asparagus': 327,
#  'quality': 328,
#  'ricotta': 329,
#  'saffron': 330,
#  'scallops': 331,
#  'crosswise': 332,
#  'grapeseed': 333,
#  'tabasco': 334,
#  'breast': 335,
#  'broken': 336,
#  'warm': 337,
#  'french': 338,
#  'brandy': 339,
#  'unbleached': 340,
#  'goat': 341,
#  'sausage': 342,
#  'mild': 343,
#  'pecans': 344,
#  'cardamom': 345,
#  'root': 346,
#  'sifted': 347,
#  'thai': 348,
#  'maple': 349,
#  'fillet': 350,
#  'hard': 351,
#  'stalk': 352,
#  'walnut': 353,
#  'milliliters': 354,
#  'berries': 355,
#  'golden': 356,
#  'cubed': 357,
#  'duck': 358,
#  'feta': 359,
#  'ears': 360,
#  'worcestershire': 361,
#  'almond': 362,
#  'combination': 363,
#  'butternut': 364,
#  'pastry': 365,
#  'strawberries': 366,
#  'imported': 367,
#  'eggplant': 368,
#  'kernels': 369,
#  'potato': 370,
#  'boiling': 371,
#  'julienned': 372,
#  'unpeeled': 373,
#  'shell': 374,
#  'loosely': 375,
#  'greek': 376,
#  'lengths': 377,
#  'dusting': 378,
#  'powdered': 379,
#  'cake': 380,
#  'watercress': 381,
#  'ready': 382,
#  'reserved': 383,
#  'cracked': 384,
#  'thighs': 385,
#  'reggiano': 386,
#  'bone': 387,
#  'shoulder': 388,
#  'halves': 389,
#  'neutral': 390,
#  'spanish': 391,
#  'dash': 392,
#  'parmigiano': 393,
#  'cranberries': 394,
#  'bulb': 395,
#  'asian': 396,
#  'scallion': 397,
#  'minutes': 398,
#  'scraped': 399,
#  'tuna': 400,
#  'pears': 401,
#  'cocoa': 402,
#  'beets': 403,
#  'total': 404,
#  'cucumbers': 405,
#  'across': 406,
#  'cognac': 407,
#  'slice': 408,
#  'whipped': 409,
#  'food': 410,
#  'liqueur': 411,
#  'leek': 412,
#  'oranges': 413,
#  'dough': 414,
#  'tart': 415,
#  'rounds': 416,
#  'chard': 417,
#  'sprouts': 418,
#  'loin': 419,
#  'cans': 420,
#  'bones': 421,
#  'country': 422,
#  'chervil': 423,
#  'arborio': 424,
#  'cheddar': 425,
#  'gold': 426,
#  'yield': 427,
#  'marjoram': 428,
#  'herbs': 429,
#  'yukon': 430,
#  'bittersweet': 431,
#  'raspberries': 432,
#  'limes': 433,
#  'left': 434,
#  'chiles': 435,
#  'julienne': 436,
#  'kale': 437,
#  'boned': 438,
#  'molasses': 439,
#  'apricots': 440,
#  'swiss': 441,
#  'anise': 442,
#  'bass': 443,
#  'pecorino': 444,
#  'mussels': 445,
#  'lentils': 446,
#  'mozzarella': 447,
#  'made': 448,
#  'prosciutto': 449,
#  'salted': 450,
#  'then': 451,
#  'steaks': 452,
#  'over': 453,
#  'clams': 454,
#  'tender': 455,
#  'cherries': 456,
#  'puree': 457,
#  'creme': 458,
#  'crème': 459,
#  'chops': 460,
#  'pineapple': 461,
#  'vermouth': 462,
#  'boiled': 463,
#  'ends': 464,
#  'cauliflower': 465,
#  'overnight': 466,
#  'mixture': 467,
#  'active': 468,
#  'tied': 469,
#  'granny': 470,
#  'steak': 471,
#  'bottle': 472,
#  'blueberries': 473,
#  'romaine': 474,
#  'added': 475,
#  'picked': 476,
#  'liquid': 477,
#  'bouquet': 478,
#  'tofu': 479,
#  'pure': 480,
#  'smith': 481,
#  'until': 482,
#  'scant': 483,
#  'mashed': 484,
#  'florets': 485,
#  'spray': 486,
#  'nonfat': 487,
#  'short': 488,
#  'flavored': 489,
#  'sprinkling': 490,
#  'instant': 491,
#  'gelatin': 492,
#  'champagne': 493,
#  'bourbon': 494,
#  'chickpeas': 495,
#  'fraiche': 496,
#  'seasoned': 497,
#  'fruit': 498,
#  'their': 499,
#  'regular': 500,
#  'spaghetti': 501,
#  'safflower': 502,
#  'porcini': 503,
#  'shoots': 504,
#  'pomegranate': 505,
#  'horseradish': 506,
#  'cooled': 507,
#  'fraîche': 508,
#  'tightly': 509,
#  'chips': 510,
#  'bitters': 511,
#  'round': 512,
#  'artichokes': 513,
#  'gruyère': 514,
#  'grape': 515,
#  'markets': 516,
#  'generous': 517,
#  'dashes': 518,
#  'bite': 519,
#  'peaches': 520,
#  'caraway': 521,
#  'currants': 522,
#  'wide': 523,
#  'drizzling': 524,
#  'japanese': 525,
#  'baguette': 526,
#  'semisweet': 527,
#  'tortillas': 528,
#  'hazelnuts': 529,
#  'avocado': 530,
#  'spice': 531,
#  'turnips': 532,
#  'prepared': 533,
#  'garni': 534,
#  'eggplants': 535,
#  'organic': 536,
#  'oyster': 537,
#  'star': 538,
#  'your': 539,
#  'handful': 540,
#  'russet': 541,
#  'simple': 542,
#  'quinoa': 543,
#  'grapefruit': 544,
#  'shells': 545,
#  'crust': 546,
#  'necessary': 547,
#  'substitute': 548,
#  'peanuts': 549,
#  'possible': 550,
#  'pods': 551,
#  'loaf': 552,
#  'idaho': 553,
#  'candied': 554,
#  'sheets': 555,
#  'hulled': 556,
#  'shortening': 557,
#  'paper': 558,
#  'pancetta': 559,
#  'seedless': 560,
#  'radishes': 561,
#  'crab': 562,
#  'radicchio': 563,
#  'linguine': 564,
#  'penne': 565,
#  'deep': 566,
#  'quarters': 567,
#  'ketchup': 568,
#  'mushroom': 569,
#  'slab': 570,
#  'superfine': 571,
#  'free': 572,
#  'shucked': 573,
#  'percent': 574,
#  'puréed': 575,
#  'seasoning': 576,
#  'roast': 577,
#  'steamed': 578,
#  'vodka': 579,
#  'dish': 580,
#  'mango': 581,
#  'using': 582,
#  'pistachios': 583,
#  'figs': 584,
#  'rings': 585,
#  'drops': 586,
#  'some': 587,
#  'cured': 588,
#  'discarded': 589,
#  'spring': 590,
#  'coffee': 591,
#  'thoroughly': 592,
#  'snapper': 593,
#  'reduced': 594,
#  'salad': 595,
#  'beer': 596,
#  'weight': 597,
#  'legs': 598,
#  'heaping': 599,
#  'blue': 600,
#  'lobsters': 601,
#  'prunes': 602,
#  'pints': 603,
#  'cremini': 604,
#  'bulgur': 605,
#  'lard': 606,
#  'romano': 607,
#  'grass': 608,
#  'tiny': 609,
#  'above': 610,
#  'sharp': 611,
#  'stale': 612,
#  'threads': 613,
#  'dozen': 614,
#  'thawed': 615,
#  'dredging': 616,
#  'stem': 617,
#  'sweetened': 618,
#  'including': 619,
#  'pureed': 620,
#  'rolled': 621,
#  'chestnuts': 622,
#  'center': 623,
#  'pink': 624,
#  'sized': 625,
#  'oysters': 626,
#  'enough': 627,
#  'unflavored': 628,
#  'endive': 629,
#  'gruyere': 630,
#  'halibut': 631,
#  'plums': 632,
#  'rhubarb': 633,
#  'flaky': 634,
#  'squid': 635,
#  'brussels': 636,
#  'less': 637,
#  'stores': 638,
#  'couscous': 639,
#  'parsnips': 640,
#  'clarified': 641,
#  'slightly': 642,
#  'make': 643,
#  'basmati': 644,
#  'oats': 645,
#  'several': 646,
#  'port': 647,
#  'patted': 648,
#  'mirin': 649,
#  'meal': 650,
#  'uncooked': 651,
#  'caviar': 652,
#  'chuck': 653,
#  'fava': 654,
#  'depending': 655,
#  'lump': 656,
#  'bottled': 657,
#  'five': 658,
#  'crusty': 659,
#  'packages': 660,
#  'pearl': 661,
#  'sunflower': 662,
#  'mexican': 663,
#  'bulbs': 664,
#  'slivers': 665,
#  'tops': 666,
#  'raspberry': 667,
#  'crusts': 668,
#  'dates': 669,
#  'little': 670,
#  'barley': 671,
#  'pans': 672,
#  'ancho': 673,
#  'blackberries': 674,
#  'anchovies': 675,
#  'brushing': 676,
#  'chipotle': 677,
#  'dissolved': 678,
#  'shaved': 679,
#  'agave': 680,
#  'defrosted': 681,
#  'divided': 682,
#  'clam': 683,
#  'herb': 684,
#  'hearts': 685,
#  'wings': 686,
#  'below': 687,
#  'truffle': 688,
#  'hours': 689,
#  'polenta': 690,
#  'html': 691,
#  'strong': 692,
#  'lukewarm': 693,
#  'tough': 694,
#  'avocados': 695,
#  'specialty': 696,
#  'substituted': 697,
#  'amount': 698,
#  'tartar': 699,
#  'juniper': 700,
#  'fruity': 701,
#  'least': 702,
#  'pickled': 703,
#  'margarine': 704,
#  'best': 705,
#  'blanc': 706,
#  'purple': 707,
#  'angostura': 708,
#  'fleshed': 709,
#  'littleneck': 710,
#  'jumbo': 711,
#  'trout': 712,
#  'livers': 713,
#  'fettuccine': 714,
#  'rolling': 715,
#  'baked': 716,
#  'four': 717,
#  'chorizo': 718,
#  'boston': 719,
#  'sake': 720,
#  'watermelon': 721,
#  'aged': 722,
#  'summer': 723,
#  'mace': 724,
#  'winter': 725,
#  'pear': 726,
#  'both': 727,
#  'equal': 728,
#  'skim': 729,
#  'purée': 730,
#  'lobster': 731,
#  'plump': 732,
#  'english': 733,
#  'leftover': 734,
#  'fleur': 735,
#  'high': 736,
#  'tenderloin': 737,
#  'topping': 738,
#  'firmly': 739,
#  'portobello': 740,
#  'snow': 741,
#  'rich': 742,
#  'buckwheat': 743,
#  'through': 744,
#  'cheesecloth': 745,
#  'smaller': 746,
#  'grapes': 747,
#  'marnier': 748,
#  'grand': 749,
#  'blood': 750,
#  'flounder': 751,
#  'snipped': 752,
#  'strip': 753,
#  'rose': 754,
#  'sausages': 755,
#  'nectar': 756,
#  'excess': 757,
#  'banana': 758,
#  'also': 759,
#  'squares': 760,
#  'bananas': 761,
#  'striped': 762,
#  'mortar': 763,
#  'morels': 764,
#  'changes': 765,
#  'young': 766,
#  'sheet': 767,
#  'aleppo': 768,
#  'bran': 769,
#  'quarter': 770,
#  'miso': 771,
#  'tahini': 772,
#  'beet': 773,
#  'heart': 774,
#  'apricot': 775,
#  'sirloin': 776,
#  'skins': 777,
#  'salsa': 778,
#  'phyllo': 779,
#  'three': 780,
#  'choice': 781,
#  'diagonal': 782,
#  'snap': 783,
#  'branches': 784,
#  'artichoke': 785,
#  'pecan': 786,
#  'mascarpone': 787,
#  'belgian': 788,
#  'cover': 789,
#  'rabe': 790,
#  'jack': 791,
#  'crabs': 792,
#  'sichuan': 793,
#  'turnip': 794,
#  'cannellini': 795,
#  'button': 796,
#  'used': 797,
#  'cranberry': 798,
#  'chickens': 799,
#  'processor': 800,
#  'bowl': 801,
#  'espresso': 802,
#  'wedge': 803,
#  'stone': 804,
#  'monkfish': 805,
#  'twist': 806,
#  'kidney': 807,
#  'fronds': 808,
#  'croutons': 809,
#  'butcher': 810,
#  'poblano': 811,
#  'caps': 812,
#  'outer': 813,
#  'vegetables': 814,
#  'madeira': 815,
#  'tomatillos': 816,
#  'nonstick': 817,
#  'bird': 818,
#  'hungarian': 819,
#  'spicy': 820,
#  'that': 821,
#  'another': 822,
#  'korean': 823,
#  'intact': 824,
#  'scotch': 825,
#  'cashews': 826,
#  'sole': 827,
#  'panko': 828,
#  'crackers': 829,
#  'basic': 830,
#  'unblemished': 831,
#  'variety': 832,
#  'ones': 833,
#  'assorted': 834,
#  'sold': 835,
#  'tequila': 836,
#  'lima': 837,
#  'this': 838,
#  'navel': 839,
#  'clover': 840,
#  'than': 841,
#  'diameter': 842,
#  'waxy': 843,
#  'fried': 844,
#  'have': 845,
#  'pinot': 846,
#  'double': 847,
#  'radish': 848,
#  'sorrel': 849,
#  'string': 850,
#  'bibb': 851,
#  'poached': 852,
#  'moons': 853,
#  'side': 854,
#  'pizza': 855,
#  'queso': 856,
#  'neck': 857,
#  'sparkling': 858,
#  'pinches': 859,
#  'preserves': 860,
#  'either': 861,
#  'heaped': 862,
#  'farro': 863,
#  'sriracha': 864,
#  'tamarind': 865,
#  'rabbit': 866,
#  'them': 867,
#  'okra': 868,
#  'pressed': 869,
#  'tips': 870,
#  'masala': 871,
#  'splash': 872,
#  'hazelnut': 873,
#  'hoisin': 874,
#  'crisp': 875,
#  'shanks': 876,
#  'vietnamese': 877,
#  'savoy': 878,
#  'monterey': 879,
#  'oriental': 880,
#  'poppy': 881,
#  'whiskey': 882,
#  'sauvignon': 883,
#  'pestle': 884,
#  'liver': 885,
#  'garam': 886,
#  'without': 887,
#  'strained': 888,
#  'preserved': 889,
#  'square': 890,
#  'kirby': 891,
#  'quick': 892,
#  'lemongrass': 893,
#  'adobo': 894,
#  'grease': 895,
#  'gram': 896,
#  'spears': 897,
#  'daikon': 898,
#  'toast': 899,
#  'swordfish': 900,
#  'live': 901,
#  'cointreau': 902,
#  'shad': 903,
#  'jelly': 904,
#  'shops': 905,
#  'brisket': 906,
#  'thickly': 907,
#  'puff': 908,
#  'pernod': 909,
#  'maldon': 910,
#  'curly': 911,
#  'kirsch': 912,
#  'couple': 913,
#  'eighths': 914,
#  'chanterelles': 915,
#  'starch': 916,
#  'fusilli': 917,
#  'fresco': 918,
#  'european': 919,
#  'vermicelli': 920,
#  'deribbed': 921,
#  'turbinado': 922,
#  'salata': 923,
#  'breadcrumbs': 924,
#  'maraschino': 925,
#  'mill': 926,
#  'matchsticks': 927,
#  'gluten': 928,
#  'liquor': 929,
#  'follows': 930,
#  'persian': 931,
#  'weighing': 932,
#  'rolls': 933,
#  'meyer': 934,
#  'collard': 935,
#  'envelope': 936,
#  'club': 937,
#  'kaffir': 938,
#  'calvados': 939,
#  'savory': 940,
#  'butt': 941,
#  'acorn': 942,
#  'warmed': 943,
#  'soba': 944,
#  'fontina': 945,
#  'delicious': 946,
#  'together': 947,
#  'cottage': 948,
#  'kalamata': 949,
#  'remove': 950,
#  'knife': 951,
#  'just': 952,
#  'bouillon': 953,
#  'macaroni': 954,
#  'tamari': 955,
#  'endives': 956,
#  'sections': 957,
#  'tail': 958,
#  'farfalle': 959,
#  'jicama': 960,
#  'brand': 961,
#  'reserve': 962,
#  'coating': 963,
#  'escarole': 964,
#  'demerara': 965,
#  'handfuls': 966,
#  'sourdough': 967,
#  'semolina': 968,
#  'roots': 969,
#  'flank': 970,
#  'bosc': 971,
#  'inner': 972,
#  'middle': 973,
#  'orzo': 974,
#  'evaporated': 975,
#  'currant': 976,
#  'portions': 977,
#  'concentrate': 978,
#  'dutch': 979,
#  'meaty': 980,
#  'graham': 981,
#  'marinara': 982,
#  'solid': 983,
#  'cookies': 984,
#  'juiced': 985,
#  'pinto': 986,
#  'membranes': 987,
#  'soup': 988,
#  'nuoc': 989,
#  'napa': 990,
#  'brioche': 991,
#  'flesh': 992,
#  'peach': 993,
#  'vidalia': 994,
#  'scaled': 995,
#  'husked': 996,
#  'iceberg': 997,
#  'habanero': 998,
#  'butterflied': 999,
#  ...}

# %%
token2subwords = make_token2subwords(word2id, ngramm2id, n_list=n_list)
token2subwords
# Out:
# {0: [2912, 2796, 2759, 3081],
#  1: [2949, 2632, 2633, 2967, 2839, 2763, 3061, 2745, 2636, 2988],
#  2: [2656, 2783, 3000, 2763, 3061, 2745, 2636],
#  3: [2687, 2851, 2941, 3090, 2843, 3027],
#  4: [3091, 3024, 2724],
#  5: [2843, 2808, 3090, 2843, 3006],
#  6: [2922, 2749, 2756],
#  7: [2785, 3035, 3100, 2677, 2861],
#  8: [2949, 2632, 2633, 2967, 2839, 2763, 3061, 2745, 2636],
#  9: [3109, 3021, 2839, 2697],
#  10: [2949, 3000, 2894, 2656],
#  11: [3109, 3021, 2839, 2697, 2692, 2846],
#  12: [3061, 3100, 2677, 2861],
#  13: [2771, 3020, 2932, 2961],
#  14: [3080, 2898, 3028, 3020, 2857],
#  15: [2843, 2899, 2809, 2967, 3027],
#  16: [2938, 2841, 2830, 2809, 2846],
#  17: [2656, 2783, 3000, 2763, 3061, 2745, 2636, 2988],
#  18: [2844, 2898, 2886, 2698],
#  19: [2683, 2841, 2906, 2814, 3027],
#  20: [2842, 2813, 2973, 2656, 3006],
#  21: [3100, 2677, 2906, 2814, 2839],
#  22: [2633, 2844, 2977, 2903],
#  23: [2704, 2731, 3080, 2898],
#  24: [2632, 2869, 3100, 2813],
#  25: [3061, 3100, 2677, 2861, 2787],
#  26: [2963, 2974, 2857, 2814],
#  27: [2936, 3020, 2857, 2814, 3027],
#  28: [2946, 2767, 2685, 2656],
#  29: [2841, 2976, 3031],
#  30: [2841, 2906, 2687],
#  31: [2967, 2855, 2699, 2636],
#  32: [3005, 2928, 2987, 2961, 2839],
#  33: [2967, 2783, 3040, 2961, 2839],
#  34: [2636, 3073, 2951, 2636],
#  35: [2920, 3027, 2942, 2836, 2874],
#  36: [2684, 2779, 3024, 3033],
#  37: [2785, 2991, 3099, 2656, 3027],
#  38: [2641, 2928, 3100, 2741],
#  39: [3041, 3099, 2656, 3006],
#  40: [2659, 2968, 2918, 2991],
#  41: [2952, 2712, 2835, 3027],
#  42: [2931, 2898, 2890, 2936, 2967, 2947],
#  43: [2910, 2841, 2830],
#  44: [2761, 2765, 2886, 2723, 2841],
#  45: [3037, 2810, 3070],
#  46: [2687, 2767, 2857, 2903, 2919, 2962],
#  47: [2699, 2852, 3021],
#  48: [2761, 2841, 2830, 3003, 3080, 2898],
#  49: [2942, 2857, 2814, 3027],
#  50: [2677, 2988, 3091, 3024, 2724, 2656, 3027],
#  51: [3063, 3021, 2783, 2760],
#  52: [3100, 2677, 2906, 2814],
#  53: [2941, 2709, 2772, 2951, 2636, 3012, 3024],
#  54: [2946, 2851, 2771, 2967],
#  55: [3091, 3071, 2710, 2814],
#  56: [3031, 2834, 2779, 3099, 3031, 2671, 2839],
#  57: [3015, 2879, 2697, 2909, 3006],
#  58: [2785, 3021, 2899, 2962],
#  59: [3003, 2935, 3026],
#  60: [2683, 2747, 2811],
#  61: [2785, 2991, 2760, 3086],
#  62: [2961, 3003, 2698, 2980, 2949, 2632, 2633, 2967],
#  63: [2992, 3054, 2732, 2920],
#  64: [2687, 2909, 2899, 2839, 2795],
#  65: [2992, 2767, 2841, 2930, 2846],
#  66: [2971, 3001, 2898, 2890, 2795, 2809, 2846],
#  67: [2788, 2835, 3022, 2814, 2839],
#  68: [2723, 2841, 3050, 2698, 3006],
#  69: [3080, 2898, 2868, 3073, 2840, 2697],
#  70: [2795, 2899, 3027, 2787],
#  71: [3061, 2675, 3087, 2643, 3006],
#  72: [2712, 2857, 2814],
#  73: [2795, 2899, 3027, 2643, 3027],
#  74: [2936, 3020, 2857, 2814, 2839],
#  75: [2918, 2712, 2819, 3083, 2920, 3027],
#  76: [2909, 2783, 3040, 3078],
#  77: [3005, 2928, 2987, 2961],
#  78: [2894, 3031, 2653, 2903],
#  79: [2680, 3021, 2827, 3008, 3006, 2991, 2632, 2633, 2846],
#  80: [2910, 2685, 2992],
#  81: [2788, 2841, 2906, 2687],
#  82: [2763, 2680, 2712, 2871, 3026],
#  83: [2815, 3021, 2783, 2789],
#  84: [2636, 3073, 2951, 2636, 2988],
#  85: [2967, 2783, 2655],
#  86: [2913, 2777, 2887, 2841, 3050],
#  87: [2828, 2741, 2714, 3061, 2879, 2795],
#  88: [2712, 2725, 2843],
#  89: [2643, 2839, 2703, 2765, 3021, 3027],
#  90: [2913, 3000, 2703, 2747],
#  91: [2814, 2809, 2967, 3006, 2897],
#  92: [3061, 2853, 2949, 3099, 3031, 2671, 2839],
#  93: [2970, 3070, 2894, 2949, 2898, 2720],
#  94: [3020, 2819, 2920],
#  95: [2689, 2664, 3024, 3033, 3020, 2951, 2636, 2988],
#  96: [2992, 2767, 2841],
#  97: [2852, 2991, 2907, 3050, 2698],
#  98: [2992, 2767, 2857, 2903],
#  99: [2658, 2907, 3073, 2747, 3033, 2844],
#  100: [2971, 2852, 2868],
#  101: [2815, 3035, 2853, 2992],
#  102: [2971, 2745, 3049, 2919, 3027],
#  103: [3021, 2855, 2699, 2987, 2961, 3027],
#  104: [2878, 2747, 2844, 2907, 2976, 2918, 3035],
#  105: [2878, 2841, 2644, 3012, 2760, 2699, 2636],
#  106: [3063, 2744, 3070, 2697, 2909, 3027],
#  107: [2664, 2907, 2644, 2830, 3027],
#  108: [2952, 2991, 2953, 2841, 2830, 3027],
#  109: [3014, 3024, 2757],
#  110: [3052, 2870, 2899, 2980],
#  111: [2815, 3035, 2675, 2958],
#  112: [3031, 3001, 3000, 2894, 2656, 3027],
#  113: [3021, 3022, 2878, 2725, 2843],
#  114: [2970, 3070, 2697, 2964, 3035, 2745, 2834, 3086],
#  115: [2931, 2898, 2726, 2920, 2839, 3091, 2907],
#  116: [2971, 3001, 2898, 2890, 2795],
#  117: [2922, 2874, 2683, 2841],
#  118: [3014, 3024, 2862, 2961, 3027],
#  119: [3031, 2834, 2779, 3099, 3031],
#  120: [2664, 2898, 2945, 3035, 2853, 2998],
#  121: [2783, 2977, 2687],
#  122: [2703, 3043, 2696],
#  123: [2697, 3014, 3024, 3033, 2928, 2853, 2998],
#  124: [2971, 2745, 3049, 2887, 2841, 3050],
#  125: [2971, 2852, 3021, 3027],
#  126: [2683, 2841, 2976],
#  127: [2696, 2839, 2894],
#  128: [2853, 2992, 2909, 3006],
#  129: [2938, 2841, 2830],
#  130: [2971, 2852, 2712, 2729, 2907, 2861, 2643, 3006],
#  131: [2830, 2899, 3027, 2643, 3027],
#  132: [2795, 3006, 2804, 2761, 2841, 3050],
#  133: [3020, 2871, 2826, 3039, 2782, 2846],
#  134: [2712, 2841, 2988, 2795, 3027],
#  135: [2922, 3056, 3095, 2839],
#  136: [2641, 2844, 2777, 2919, 2839],
#  137: [2843, 2783, 2907, 2762, 2813],
#  138: [3095, 2783, 2907, 2988],
#  139: [2842, 2677, 2906, 2687],
#  140: [3089, 2853, 2656],
#  141: [2664, 2646, 2713, 2962, 2644, 2830],
#  142: [3109, 3035, 2834],
#  143: [2685, 2949, 3024, 3020, 2729, 2907],
#  144: [2687, 2767, 2747, 3020],
#  145: [3020, 2674, 2919],
#  146: [3039, 2973, 2706],
#  147: [2964, 3021, 2827],
#  148: [3021, 3022, 2878, 2725, 2843, 2839],
#  149: [2990, 2794, 2772, 2819, 2920, 2839],
#  150: [2713, 2809, 3033, 2928, 2675],
#  151: [2659, 2968, 2918, 2991, 2977, 2776],
#  152: [3020, 2871, 2826, 3039],
#  153: [2931, 2977, 2903, 2919, 3027],
#  154: [2843, 2808, 3090, 2843, 3006, 2890],
#  155: [2795, 2839, 3091, 2760, 2920],
#  156: [2931, 3000, 2894, 2656],
#  157: [2697, 2909, 3006, 2945, 2897],
#  158: [2762, 2813, 3094, 2920, 3003],
#  159: [3041, 3000, 2697, 2909, 3027],
#  160: [3035, 2879, 2795, 2855, 2779, 2898, 2897],
#  161: [3095, 2783, 3099, 2656, 2962],
#  162: [3107, 2640, 2898, 2817, 2656, 3006, 3021, 3027],
#  163: [2869, 2636, 2830, 2809, 2967, 2839, 3072],
#  164: [2687, 2767, 2932, 2961, 2839],
#  165: [2942, 3055, 2797, 2636],
#  166: [3095, 2899, 2827],
#  167: [3095, 2809, 3033],
#  168: [2884, 2966, 2799, 2741, 2817],
#  169: [2705, 2898, 3101],
#  170: [2851, 2636, 2830, 2947],
#  171: [2942, 2857, 2814],
#  172: [3061, 2852, 3101],
#  173: [3035, 2745, 2834],
#  174: [2656, 2855, 3062, 2843, 3006, 2991, 3099, 2904, 2741, 3021],
#  175: [2938, 2747, 3033, 2967, 2980, 2998],
#  176: [3035, 3100, 2731, 2826, 2692, 2846],
#  177: [3063, 2744, 2874, 2982, 2793],
#  178: [2664, 2907, 3089, 2771, 2844],
#  179: [2788, 2685, 2973, 2656, 3027],
#  180: [2938, 2840, 2697],
#  181: [2971, 2771, 2648],
#  182: [2961, 3006, 2897],
#  183: [2697, 2964, 3021, 3027, 3051, 2643, 3027],
#  184: [2894, 2656, 2855, 3086],
#  185: [2967, 2962, 3050, 2682, 2992, 3019, 2910, 2840, 2795],
#  186: [2920, 2809, 2724, 2656, 3027],
#  187: [2843, 2808, 3090, 2843, 3006, 2937, 2971, 2852, 2868, 2988],
#  188: [3005, 2967, 2783, 2907, 2830, 3027],
#  189: [2697, 2964, 2712, 2819, 3062],
#  190: [3109, 3035, 2751, 2696, 2962],
#  191: [3008, 2962, 2644, 2830, 2809],
#  192: [2894, 2918, 2712, 2725, 2756],
#  193: [2894, 2656, 2855, 3083, 2920, 3027],
#  194: [2784, 3032, 2744, 2749],
#  195: [2704, 2710, 2687],
#  196: [2845, 3090, 2680, 3035, 3009, 2768, 2819, 2779, 3099, 2656, 2809, 2846],
#  197: [2894, 2772, 2857, 2903],
#  198: [2909, 2783, 2789],
#  199: [2884, 2771, 2811, 2681],
#  200: [2641, 2844, 3099],
#  201: [2687, 2934, 2677, 3036, 2681],
#  202: [2931, 2845, 2680, 2712, 2674, 3045],
#  203: [2852, 3021, 3003, 3080, 2907, 3089],
#  204: [2913, 2977, 2971, 2636],
#  205: [3037, 2844, 2953, 2841],
#  206: [2949, 2898, 2945, 2991, 2657, 2983, 2636],
#  207: [2942, 2747, 3033],
#  208: [3024, 3096, 2699, 2636, 2861, 2787],
#  209: [2870, 2809, 3033],
#  210: [2687, 2851, 2653, 2971, 2771, 2844, 3099, 2656],
#  211: [3037, 2810, 2874],
#  212: [3063, 2744, 2874, 2982, 2633, 2967, 3027],
#  213: [2785, 2991, 2907, 2762, 3017, 2844, 3099, 2656, 3027],
#  214: [2928, 2636, 3050],
#  215: [3035, 3001, 3000, 2894, 2656, 3027],
#  216: [2969, 2649, 2705],
#  217: [2664, 2898, 2945, 3035, 2853],
#  218: [3084, 3107, 2645, 2899, 2896, 2696, 3027],
#  219: [2844, 2760, 2982],
#  220: [2870, 3027, 3060, 2698, 2839],
#  221: [2946, 2909, 2783, 3099],
#  222: [2771, 3020, 2932, 2961, 2839],
#  223: [3091, 2657, 2698],
#  224: [2999, 2887, 2841, 2930, 2967, 2839, 3072],
#  225: [2845, 3090, 3037, 2967],
#  226: [2969, 3100, 2741],
#  227: [2763, 2788, 2841, 3012, 2977, 2687],
#  228: [2851, 2834, 2920, 2855, 2779, 2789, 2643],
#  229: [2843, 2783, 3000],
#  230: [2697, 2909, 2809, 3033, 2967, 3027],
#  231: [2878, 3075, 2643, 3006],
#  232: [2971, 2852, 2868, 2988, 2894, 2949, 2898, 2937, 2687],
#  233: [3084, 3107, 2640, 3000, 2697],
#  234: [2913, 2632, 2667],
#  235: [2788, 2835, 3022, 2814],
#  236: [2913, 3024, 2831, 3091, 2760, 2683, 2857],
#  237: [2684, 2699, 3049, 2919, 3027],
#  238: [2636, 2930, 2846],
#  239: [3097, 2710, 3042, 2687, 2767, 2841, 3073],
#  240: [3041, 3024, 2993, 2762, 2813, 2998],
#  241: [2894, 2949, 3024, 2811, 2681],
#  242: [2936, 3020, 2932, 2961, 3006, 3021, 3027],
#  243: [2991, 2953, 2840, 2703, 2841, 2988],
#  244: [2795, 2808, 2931, 2898, 2991, 3099, 2656, 3027],
#  245: [2971, 2653, 2971, 2636, 2762, 2813],
#  246: [2785, 3021, 2783, 3000, 2703, 2841, 3050],
#  247: [2967, 2980, 2973, 2904, 2710, 2814],
#  248: [2938, 2765, 2726],
#  249: [2967, 2899, 2825, 2681],
#  250: [2845, 3090, 3037, 2967, 2839],
#  251: [2664, 2845, 2843, 3006, 2890],
#  252: [2785, 3021, 2899, 2962, 2988],
#  253: [2785, 2991, 2953, 2841],
#  254: [2664, 2632, 2651, 2913, 2657, 2698],
#  255: [3095, 2783, 2907],
#  256: [3091, 3024, 3096, 2699, 2636],
#  257: [3109, 2897, 2838, 2841, 3050],
#  258: [2697, 3014, 3024, 3033, 2928, 2853],
#  259: [2894, 2772, 2857, 2903, 2681],
#  260: [2920, 2783, 3099],
#  261: [2683, 2944, 2916, 3027],
#  262: [2969, 3001, 2777, 2919, 3027],
#  263: [2762, 2813, 2998],
#  264: [3040, 2658, 2953, 2747, 2844, 2632, 2633, 2967],
#  265: [2971, 2636, 2816, 3008, 3022, 2776, 2772, 2951, 2636, 2830, 3006, 2890],
#  266: [2904, 2741, 3101, 2919, 2947],
#  267: [2969, 2847, 2773, 2656, 2962, 2830, 3027],
#  268: [2961, 2783, 3024],
#  269: [2712, 2841, 2861],
#  270: [2841, 2906, 2687, 2909, 2839],
#  271: [2677, 2988, 3052, 2870, 2899, 2980, 2656, 2962, 2830, 3027],
#  272: [2842, 2813, 2973, 2656, 3006, 2726, 2683, 2747, 2811],
#  273: [2969, 2649, 2942, 2836, 2874],
#  274: [2894, 2914, 2917, 2967],
#  275: [2931, 2898, 2817, 2998],
#  276: [2983, 2745, 2649],
#  277: [2763, 2680, 2712, 2871],
#  278: [2931, 2898, 2817],
#  279: [2999, 2887, 2841],
#  280: [3024, 3033, 2831, 2763, 2788, 2857, 2814],
#  281: [3107, 2640, 2898, 2817, 2998],
#  282: [2967, 2783, 2907],
#  283: [2971, 2852, 2868, 3082, 2920, 2783, 3024],
#  284: [2779, 2646, 2884, 2636, 2644, 3012, 2953, 2840, 2795],
#  285: [2967, 2855, 2699, 2636, 2988],
#  286: [2795, 2899, 3027],
#  287: [2946, 2767, 2685, 2656, 2839],
#  288: [2687, 2767, 2747, 2967],
#  289: [2687, 2767, 2747, 3020, 2835, 2839],
#  290: [2789, 3051, 2942, 2685, 2772, 2951, 2636, 3012, 3024],
#  291: [2999, 2887, 2841, 2644, 2830, 3027],
#  292: [2943, 3024, 2844, 2845, 2843, 2962, 3089],
#  293: [2684, 2779, 3000, 2697, 2909, 3027],
#  294: [2931, 3000, 2894, 2949],
#  295: [2788, 2841, 2976],
#  296: [2815, 3021, 2783, 3000, 2894, 2998],
#  297: [2712, 2662, 2793],
#  298: [2713, 2783, 3000, 2894],
#  299: [2687, 2767, 2841, 2830, 2839, 2795],
#  300: [2843, 2899, 2809],
#  301: [2904, 2741, 2726, 2920, 3006, 2712, 2857],
#  302: [2763, 3037, 3020, 2685],
#  303: [2643, 2669, 2961, 2701, 2841, 2830, 3027],
#  304: [2922, 2741, 2945, 2897],
#  305: [2898, 2744, 2731, 2799, 3017, 2844],
#  306: [2907, 2906, 2687, 2851, 2987, 3078],
#  307: [2910, 2747, 2648],
#  308: [2922, 2710, 2922, 2874, 2982, 3095, 3006],
#  309: [2689, 3063, 2744, 3056, 2651, 3095, 3027],
#  310: [2633, 2844, 2907, 2906, 2687, 2909, 3027],
#  311: [2687, 2767, 2747, 3033, 2967, 3027],
#  312: [2969, 2847, 2773],
#  313: [2697, 2767, 3053, 2685, 2949, 2777, 2919],
#  314: [2788, 2841, 2830],
#  315: [2884, 2771, 2811],
#  316: [3031, 2852, 2868],
#  317: [2931, 2977, 2903, 3045, 2657, 2698],
#  318: [3107, 2640, 2898, 2817],
#  319: [2815, 3035, 2653, 3042, 2971, 2771, 3020],
#  320: [2795, 3006, 2945, 2991, 2907, 3089],
#  321: [2842, 2677, 2906, 2687, 2909, 2839],
#  322: [2943, 3024, 2844, 2845, 2843, 2733, 2923],
#  323: [3089, 2745, 2649, 3092, 2967, 2839],
#  324: [2909, 2783, 2789, 2787],
#  325: [2687, 2909, 3006, 2945, 2897],
#  326: [2828, 2874, 3062, 2805, 2887, 2841],
#  327: [3000, 2763, 2931, 2898, 2991, 2657, 2799, 3070],
#  328: [3107, 2640, 3024, 3020, 2685, 2914],
#  329: [2712, 2857, 2971, 2853, 2973, 2949],
#  330: [3091, 2655, 2663, 3109, 3035, 2636],
#  331: [2689, 2664, 3024, 3033, 2928, 2941, 2756],
#  332: [3063, 3035, 2879, 3072, 3052, 2910, 2840, 2795],
#  333: [2785, 2991, 2845, 2843, 2839, 2795, 2899, 3027],
#  334: [2949, 2632, 2913, 3000, 2689, 2971],
#  335: [2815, 3021, 2783, 3000, 2894],
#  336: [2815, 3035, 3049, 2919, 2962],
#  337: [3041, 2898, 2726],
#  338: [3109, 3021, 2962, 2906, 2687],
#  339: [2815, 2991, 2907, 2861, 2730],
#  340: [2677, 2752, 2633, 2967, 2783, 2977, 2687, 2909, 3027],
#  341: [2983, 3001, 3099],
#  342: [3091, 3071, 3070, 3091, 2657, 2698],
#  343: [2683, 2747, 2648],
#  344: [2843, 3022, 2664, 2907, 2988],
#  345: [2664, 2898, 2720, 2705, 2760, 2699, 2834],
#  346: [3035, 2745, 2853],
#  347: [2703, 2883, 2773, 2656, 3027],
#  348: [2992, 3014, 2953],
#  349: [2779, 2845, 3037, 2967],
#  350: [2938, 2747, 3033, 2967, 2980],
#  351: [3014, 2898, 2720],
#  352: [2894, 2949, 3024, 2811],
#  353: [3041, 3024, 2993, 2762, 2813],
#  354: [2683, 2747, 3033, 3020, 2747, 3020, 2685, 2656, 3006, 2890],
#  355: [3095, 3006, 2945, 2712, 2835, 2839],
#  356: [2983, 2771, 2648, 2643, 2962],
#  357: [2922, 3056, 3095, 3027],
#  358: [3102, 2710, 2903],
#  359: [3008, 2980, 2949],
#  360: [2783, 2898, 2890],
#  361: [2660,
#   2852,
#   2937,
#   2814,
#   2839,
#   2894,
#   2656,
#   3006,
#   2890,
#   2697,
#   2767,
#   2765,
#   3021],
#  362: [3024, 3096, 2699, 2636, 2861],
#  363: [2971, 2834, 2982, 2859, 2841, 3012, 3099, 2772, 2951, 2636],
#  364: [2842, 2813, 2973, 2656, 3006, 2868, 2762, 2813],
#  365: [2931, 3000, 2894, 2918, 2897],
#  366: [2894, 2918, 2991, 2854, 2997, 3095, 3006, 2945, 2712, 2835, 2839],
#  367: [2819, 3062, 3061, 2852, 2817, 2656, 3027],
#  368: [3003, 2935, 2735, 3037, 2844, 2907, 2976],
#  369: [2919, 3006, 2868, 2830, 2809, 2831],
#  370: [3061, 2853, 2949, 3099, 3031],
#  371: [2869, 2718, 2747, 3020, 2841, 3050],
#  372: [2963, 3017, 3020, 2835, 2962, 2644, 2830, 3027],
#  373: [2677, 2975, 2843, 2899, 2809, 2967, 3027],
#  374: [2697, 2909, 2809, 3033],
#  375: [2928, 2745, 2879, 2795, 2809, 2846],
#  376: [2785, 3021, 2899, 2825],
#  377: [2967, 2962, 3050, 2682, 2992, 2800],
#  378: [3102, 3070, 2894, 2772, 2841, 3050],
#  379: [3061, 2675, 3087, 2643, 3006, 3021, 3027],
#  380: [2664, 2777, 2919],
#  381: [3041, 3099, 2656, 3006, 2937, 3063, 3021, 2839, 3072],
#  382: [3021, 2783, 2789, 2730],
#  383: [3021, 2839, 2795, 3006, 2804, 2961, 3027],
#  384: [3063, 2991, 2977, 2903, 2919, 3027],
#  385: [2992, 2767, 2871, 2826, 2800],
#  386: [3021, 3003, 2935, 2723, 2729, 2907, 3089],
#  387: [2869, 2636, 2830],
#  388: [2697, 2851, 3100, 3017, 2648, 2643, 3006],
#  389: [3014, 3024, 2862, 2961, 2839],
#  390: [2830, 3004, 2813, 2918, 2991, 3024],
#  391: [2763, 2931, 2907, 3073, 2840, 2697],
#  392: [2705, 3000, 2697],
#  393: [2931, 2898, 2726, 2683, 2871, 2723, 2729, 2907, 3089],
#  394: [3063, 2991, 2907, 2752, 3095, 3006, 2945, 2712, 2835, 2839],
#  395: [2842, 3017, 2727],
#  396: [3000, 2703, 2729, 2907],
#  397: [2689, 2664, 3024, 3033, 3020, 2951, 2636],
#  398: [2683, 2841, 2762, 2813, 2656, 2839],
#  399: [2689, 3063, 2991, 2845, 2843, 3027],
#  400: [2904, 2677, 3012],
#  401: [2843, 2783, 2898, 2890],
#  402: [2971, 2653, 2971, 3001],
#  403: [3095, 2899, 2980, 2998],
#  404: [3031, 2853, 2949, 3024],
#  405: [2922, 2710, 2922, 2874, 2982, 3095, 3006, 2890],
#  406: [2977, 3063, 3035, 2879, 3072],
#  407: [2971, 2966, 2882, 3012, 2977],
#  408: [2936, 3020, 2857, 2814],
#  409: [2946, 2767, 2725, 3090, 2843, 3027],
#  410: [3110, 2745, 2649],
#  411: [3020, 2950, 3107, 2645, 3004, 2741],
#  412: [2967, 2899, 2825],
#  413: [2852, 2991, 2907, 3050, 2698, 2839],
#  414: [2694, 3100, 2731, 2826],
#  415: [2949, 2898, 2817],
#  416: [3035, 3100, 2677, 2861, 2787],
#  417: [2687, 3014, 2898, 2720],
#  418: [2763, 2680, 3035, 3100, 2813, 2998],
#  419: [2928, 2718, 2841],
#  420: [2664, 2907, 2988],
#  421: [2869, 2636, 2830, 2839],
#  422: [2971, 3100, 2677, 2976, 2918, 2897],
#  423: [2687, 2909, 3006, 2804, 2761, 2747],
#  424: [2898, 2929, 2869, 2852, 2712, 2951],
#  425: [2687, 2909, 3027, 3051, 2705, 2898],
#  426: [2983, 2771, 2648],
#  427: [2838, 2835, 2809, 2648],
#  428: [2779, 2898, 2902, 2797, 2852, 2991, 2760],
#  429: [2909, 3006, 2929, 2793],
#  430: [2885, 3046, 3015, 2636],
#  431: [2859, 2685, 2973, 2656, 3006, 2890, 3052, 2870, 2899, 2980],
#  432: [2991, 3000, 2763, 2986, 3095, 3006, 2945, 2712, 2835, 2839],
#  433: [3020, 2819, 2920, 2839],
#  434: [2967, 2827, 2773],
#  435: [2687, 2767, 2747, 2967, 2839],
#  436: [2963, 3017, 3020, 2835, 2962, 2644, 2830],
#  437: [3045, 3024, 2967],
#  438: [2869, 2636, 2830, 3027],
#  439: [2699, 2771, 2844, 3000, 3072, 2795, 2839],
#  440: [2845, 2680, 2712, 2857, 2971, 2853, 2998],
#  441: [3052, 2910, 2840, 3072],
#  442: [2907, 3073, 2840, 2795],
#  443: [2913, 3000, 3072],
#  444: [2843, 3022, 2971, 2852, 2712, 2841, 3089],
#  445: [2970, 3070, 3072, 2795, 2809, 2831],
#  446: [2967, 2962, 2976, 2772, 2747, 2831],
#  447: [2699, 2751, 2672, 2880, 2898, 3021, 2809, 3033, 2844],
#  448: [2779, 2789, 2643],
#  449: [2680, 3035, 2879, 2689, 2878, 2836, 2813, 2973, 3031],
#  450: [3091, 3024, 2724, 2656, 3027],
#  451: [2992, 2909, 2962],
#  452: [2894, 2656, 2783, 2777, 2681],
#  453: [2987, 2961, 3006],
#  454: [3005, 2844, 2760, 3086],
#  455: [2656, 2962, 2861, 2643, 3006],
#  456: [2687, 2909, 3006, 2945, 2712, 2835, 2839],
#  457: [2828, 2741, 3021, 2899],
#  458: [3063, 3021, 2855, 2920],
#  459: [3063, 2654, 2711, 2920],
#  460: [2687, 2851, 2941, 2756],
#  461: [2788, 2841, 2830, 2783, 2845, 3090, 3037, 2967],
#  462: [2961, 3006, 2726, 2699, 3100, 2813, 2992],
#  463: [2869, 2718, 2747, 2967, 3027],
#  464: [2962, 2861, 2787],
#  465: [2664, 3071, 3017, 3020, 2883, 2641, 2928, 2675, 2870, 3006],
#  466: [2987, 2961, 3006, 2868, 3073, 2871, 2826, 3039],
#  467: [2683, 2944, 2968, 2904, 2741, 3021],
#  468: [2977, 2776, 2772, 2932, 2961],
#  469: [2772, 2835, 3027],
#  470: [2785, 2991, 2907, 2644, 2990],
#  471: [2894, 2656, 2783, 2777],
#  472: [2869, 2853, 2973, 2782, 2967],
#  473: [2633, 2810, 2645, 3059, 3095, 3006, 2945, 2712, 2835, 2839],
#  474: [3035, 2834, 2779, 2953, 2841, 2830],
#  475: [2789, 3051, 2643, 3027],
#  476: [2788, 2857, 2903, 2919, 3027],
#  477: [3020, 2950, 3107, 2974, 3075],
#  478: [2869, 3100, 3079, 3107, 2645, 2980],
#  479: [3031, 2847, 3011],
#  480: [2828, 2741, 3021],
#  481: [2684, 2683, 2685, 2992],
#  482: [2677, 2976, 2772, 2747],
#  483: [2689, 2664, 2907, 2976],
#  484: [2779, 3000, 2697, 2909, 3027],
#  485: [2641, 2928, 2852, 3021, 2980, 2998],
#  486: [2763, 2680, 2991, 2646],
#  487: [3089, 2636, 2816, 3076, 3099],
#  488: [2697, 2851, 2852, 2817],
#  489: [2641, 2844, 3040, 3007, 2852, 3021, 3027],
#  490: [2763, 2680, 2712, 2841, 3036, 2995, 3020, 2841, 3050],
#  491: [2841, 2988, 2894, 2949, 2907, 2976],
#  492: [2698, 2809, 2844, 3099, 2772, 2841],
#  493: [2687, 3014, 2760, 3062, 2931, 2657, 2882, 2830],
#  494: [2869, 3100, 2741, 2929, 2869, 2636],
#  495: [2687, 2767, 2857, 2903, 2670, 2843, 2783, 3000],
#  496: [3109, 2991, 2953, 2857, 2687, 2909],
#  497: [2795, 2783, 3000, 2969, 2636, 2830, 3027],
#  498: [3109, 2744, 2974, 2685],
#  499: [2992, 2909, 2701, 2765],
#  500: [3021, 3003, 2799, 3017, 2844, 2898],
#  501: [2763, 2931, 2657, 2826, 2909, 2980, 2973, 2772],
#  502: [3091, 2655, 2663, 2641, 2928, 2675, 2870, 3006],
#  503: [3061, 2852, 2937, 2878, 2841, 3073],
#  504: [2697, 2851, 2745, 2853, 2998],
#  505: [3061, 2834, 2920, 3003, 2785, 2991, 2907, 3012, 3099, 2656],
#  506: [2851, 2852, 2890, 2795, 3006, 2991, 2789, 2942, 2840, 2697],
#  507: [2971, 2745, 2771, 2967, 3027],
#  508: [3109, 2991, 2873, 2665, 2687, 2909],
#  509: [2772, 2871, 2826, 3039, 2782, 2846],
#  510: [2687, 2767, 2725, 2756],
#  511: [2859, 2685, 2973, 2656, 3006, 2890],
#  512: [3035, 3100, 2677, 2861],
#  513: [2898, 2817, 2772, 2857, 2687, 2851, 3049, 2919, 2839],
#  514: [2785, 2744, 3065, 2673, 2837, 3021],
#  515: [2785, 2991, 2845, 2843],
#  516: [2779, 2898, 3101, 2919, 2980, 2998],
#  517: [2698, 2962, 2830, 3006, 3035, 3100, 3070],
#  518: [2705, 3000, 2697, 2909, 2839],
#  519: [2859, 2685, 2656],
#  520: [2843, 2783, 2977, 2687, 2909, 2839],
#  521: [2664, 2898, 2991, 2854, 3041, 2646],
#  522: [2922, 2741, 2945, 2991, 2907, 2976, 2998],
#  523: [2910, 3075, 2643],
#  524: [2952, 2712, 3043, 2672, 3010, 3020, 2841, 3050],
#  525: [2943, 2845, 2931, 2907, 2830, 2839, 2795],
#  526: [2913, 2657, 2799, 2645, 2980, 2973, 2656],
#  527: [2795, 2855, 2683, 2840, 3052, 2870, 2899, 2980],
#  528: [3031, 2852, 2817, 2772, 2747, 3033, 2844, 3000],
#  529: [3014, 2939, 2696, 2809, 2993, 2762, 2813, 2998],
#  530: [3040, 3007, 2653, 2664, 2789, 2694],
#  531: [2763, 2788, 2857, 2814],
#  532: [2904, 2741, 2868, 3073, 2725, 2756],
#  533: [2680, 3021, 2808, 2931, 2898, 3021, 3027],
#  534: [3080, 2898, 2868, 3073],
#  535: [3003, 2935, 2735, 3037, 2844, 2907, 2976, 2998],
#  536: [2852, 2886, 3080, 2907, 3073, 2857],
#  537: [2679, 2778, 2894, 2656, 3006],
#  538: [2894, 2949, 2898],
#  539: [2884, 3100, 2741],
#  540: [3014, 2907, 2861, 2803, 3011, 3017],
#  541: [2744, 3070, 3072, 2795, 2980],
#  542: [2703, 2819, 3062, 3037, 2967],
#  543: [3107, 2974, 2841, 3089, 3001],
#  544: [2785, 2991, 2845, 2843, 2827, 3109, 2744, 2974, 2685],
#  545: [2697, 2909, 2809, 3033, 2831],
#  546: [3063, 2744, 3070, 2894],
#  547: [2830, 3022, 2814, 2839, 3072, 3091, 2898, 2897],
#  548: [2704, 3056, 2793, 2894, 2772, 2685, 2904, 2813, 2656],
#  549: [2843, 2783, 2907, 2762, 2813, 2998],
#  550: [3061, 2879, 3072, 2703, 2662, 2633, 2967],
#  551: [3061, 2649, 2787],
#  552: [2928, 3001, 2655],
#  553: [3075, 2705, 2876, 2851],
#  554: [2664, 2907, 2861, 2942, 2835, 3027],
#  555: [2697, 2909, 2899, 2980, 2998],
#  556: [2934, 3017, 3033, 2967, 3027],
#  557: [2697, 2851, 2852, 2817, 2656, 2962, 3073, 2841, 3050],
#  558: [2931, 2845, 2843, 3006],
#  559: [2931, 2907, 2906, 2814, 2980, 2973, 2949],
#  560: [2795, 2899, 3027, 3092, 2967, 2839, 3072],
#  561: [2991, 2789, 2942, 2840, 2697, 2909, 2839],
#  562: [3063, 2991, 2632],
#  563: [2991, 2789, 2942, 2857, 3042, 2687, 2767, 2951],
#  564: [3020, 2841, 3050, 2799, 2974, 2841, 2830],
#  565: [2843, 2962, 2644, 2830],
#  566: [2643, 2899, 2808],
#  567: [3107, 2640, 2898, 2817, 2656, 3006, 2890],
#  568: [2919, 2980, 2908, 2687, 2934, 2749],
#  569: [2970, 3070, 2697, 2964, 3035, 2745, 2834],
#  570: [2936, 2844, 2632],
#  571: [2704, 2749, 2843, 3006, 2738, 2938, 2841, 2830],
#  572: [3109, 3021, 2899],
#  573: [2697, 2934, 2710, 2903, 2919, 3027],
#  574: [2843, 3006, 2937, 2814, 2962, 2976],
#  575: [2828, 2741, 2905, 2893, 3027],
#  576: [2795, 2783, 3000, 2969, 2636, 3073, 2841, 3050],
#  577: [3035, 3001, 3000, 2894],
#  578: [2894, 2656, 2783, 2760, 2920, 3027],
#  579: [3007, 2649, 2866, 3045],
#  580: [2942, 2840, 2697],
#  581: [2779, 2907, 3050, 2983],
#  582: [3070, 2703, 2841, 3050],
#  583: [2788, 2840, 2894, 2949, 2977, 2687, 2767, 2951, 2879],
#  584: [2938, 2871, 3026],
#  585: [2712, 2841, 3050, 3026],
#  586: [2952, 3035, 2941, 2756],
#  587: [2969, 2834, 2920],
#  588: [2922, 2741, 3021, 3027],
#  589: [2942, 2840, 2689, 2664, 2898, 2720, 2643, 3027],
#  590: [2763, 2680, 2712, 2841, 3050],
#  591: [2971, 2847, 2663, 3008, 2899],
#  592: [2992, 2851, 2852, 3035, 3100, 2731, 2826, 2692, 2846],
#  593: [2739, 3012, 2845, 3090, 2843, 3006],
#  594: [3021, 3027, 3102, 2710, 2814, 3027],
#  595: [3091, 3024, 2844, 2789],
#  596: [3095, 2899, 3006],
#  597: [2870, 2701, 2871, 2826, 3039],
#  598: [2967, 3003, 3026],
#  599: [2909, 2783, 2845, 2788, 2841, 3050],
#  600: [2633, 2810, 2645],
#  601: [2928, 2888, 2793, 2894, 2656, 3006, 2890],
#  602: [2680, 2744, 2677, 2830, 2839],
#  603: [2788, 2841, 2976, 2998],
#  604: [3063, 3021, 2855, 2683, 2841, 3073],
#  605: [2842, 3017, 3038, 2799, 2741],
#  606: [2844, 2898, 2720],
#  607: [3035, 2834, 2779, 2907, 3089],
#  608: [2785, 2991, 3000, 3072],
#  609: [2772, 2841, 2990],
#  610: [2632, 2869, 2987, 2961],
#  611: [2697, 3014, 2898, 2714],
#  612: [2894, 2949, 3024, 2967],
#  613: [2992, 2964, 3021, 2783, 2789, 2787],
#  614: [2694, 2751, 2696, 2962],
#  615: [2992, 3014, 2854, 2870, 3027],
#  616: [2952, 3021, 3027, 3060, 2723, 2841, 3050],
#  617: [2894, 2656, 2855],
#  618: [3052, 2870, 2899, 2980, 2656, 2962, 2830, 3027],
#  619: [2841, 2906, 3005, 2810, 2693, 2942, 2841, 3050],
#  620: [2828, 2741, 3021, 2899, 3027],
#  621: [3035, 2771, 3033, 2967, 3027],
#  622: [2687, 2909, 2839, 2894, 2848, 2762, 2813, 2998],
#  623: [2814, 2962, 2976, 2656, 3006],
#  624: [2788, 2841, 3036],
#  625: [2703, 3043, 2696, 3027],
#  626: [2679, 2778, 2894, 2656, 3006, 2890],
#  627: [2962, 3089, 3100, 2731, 2826],
#  628: [2677, 2816, 2641, 2844, 3040, 3007, 2852, 3021, 3027],
#  629: [2962, 2861, 2942, 2932, 2961],
#  630: [2785, 2744, 3065, 2713, 3006, 3021],
#  631: [3014, 3024, 3020, 2662, 2842, 2813],
#  632: [3037, 2810, 2874, 3086],
#  633: [2812, 2934, 3056, 2913, 2898, 2929],
#  634: [2641, 2844, 2777, 2758],
#  635: [3084, 3107, 2974, 3075],
#  636: [2815, 2744, 3070, 3072, 2795, 2809, 2831],
#  637: [2967, 2839, 3072],
#  638: [2894, 3031, 2852, 3021, 2839],
#  639: [2971, 3100, 3070, 2689, 2971, 3100, 3070],
#  640: [2931, 2898, 2890, 2739, 3073, 2725, 2756],
#  641: [3005, 2844, 2898, 2712, 2883, 2938, 2835, 3027],
#  642: [2936, 3020, 2871, 2826, 3039, 2782, 2846],
#  643: [2779, 2777, 2919],
#  644: [2913, 3000, 2684, 2779, 3099, 2772],
#  645: [3001, 3099, 2998],
#  646: [2795, 2669, 2961, 3006, 2991, 3024],
#  647: [3061, 2852, 2817],
#  648: [2931, 3099, 2973, 2656, 3027],
#  649: [2683, 2765, 2712, 2841],
#  650: [2920, 2783, 3024],
#  651: [2677, 2906, 2971, 2745, 3049, 2919, 3027],
#  652: [2664, 3040, 2761, 2729, 2898],
#  653: [2687, 2934, 2710, 2903],
#  654: [3076, 3040, 2658],
#  655: [2643, 2808, 2843, 2962, 2861, 2942, 2841, 3050],
#  656: [2810, 2874, 3062],
#  657: [2869, 2853, 2973, 2782, 2967, 3027],
#  658: [2938, 2932, 2961],
#  659: [3063, 2744, 3070, 2894, 2914],
#  660: [2931, 2977, 2903, 3045, 2657, 2698, 2839],
#  661: [2843, 2783, 2898, 3028],
#  662: [2704, 2677, 2816, 2641, 2928, 2675, 2870, 3006],
#  663: [2920, 2659, 2768, 2857, 2664, 2907],
#  664: [2842, 3017, 2727, 2793],
#  665: [2936, 3020, 2932, 2961, 3006, 2890],
#  666: [3031, 2941, 2756],
#  667: [2991, 3000, 2763, 2986, 3095, 3006, 2945, 2897],
#  668: [3063, 2744, 3070, 2894, 2998],
#  669: [2705, 3099, 2656, 2839],
#  670: [3020, 2685, 2973, 2782, 2967],
#  671: [2913, 2898, 3028, 2967, 2947],
#  672: [2931, 2907, 2988],
#  673: [2907, 2906, 2687, 2851],
#  674: [2633, 2844, 2977, 2903, 2891, 3095, 3006, 2945, 2712, 2835, 2839],
#  675: [2907, 2906, 2687, 2851, 2987, 2761, 2835, 2839],
#  676: [2815, 2744, 3070, 2697, 2767, 2841, 3050],
#  677: [2687, 2767, 2725, 3061, 2853, 2782, 2967],
#  678: [2942, 2840, 3072, 2969, 2771, 2862, 2961, 3027],
#  679: [2697, 3014, 3040, 2961, 3027],
#  680: [2657, 3080, 3040, 2961],
#  681: [2643, 2827, 3109, 3035, 2879, 2894, 2656, 3027],
#  682: [2942, 2932, 2761, 3075, 2643, 3027],
#  683: [3005, 2844, 2760],
#  684: [2909, 3006, 2929],
#  685: [2909, 2783, 2898, 2817, 2998],
#  686: [2910, 2841, 3050, 3026],
#  687: [3095, 2809, 2928, 2675],
#  688: [2918, 2744, 2989, 2663, 2641, 2967],
#  689: [2851, 3100, 2741, 2890],
#  690: [3061, 2771, 2967, 2962, 2976, 2949],
#  691: [3039, 3094, 2829],
#  692: [2894, 2918, 3035, 2636, 3050],
#  693: [2810, 3046, 2919, 2889, 3041, 2898, 2726],
#  694: [3031, 3100, 2731, 2826],
#  695: [3040, 3007, 2653, 2664, 2789, 2694, 2879],
#  696: [2763, 2843, 3022, 2878, 2729, 3024, 2724, 2914],
#  697: [2704, 3056, 2793, 2894, 2772, 2685, 2904, 2813, 2656, 3027],
#  698: [2760, 2699, 3100, 2677, 2976],
#  699: [2949, 2898, 2817, 2949, 2898],
#  700: [2963, 2677, 3073, 2725, 2843, 3006],
#  701: [3109, 2744, 2974, 2685, 2914],
#  702: [2967, 2783, 3000, 2894],
#  703: [2788, 2857, 2903, 2995, 2967, 3027],
#  704: [2779, 2898, 2886, 3080, 2898, 2712, 2841, 2830],
#  705: [3095, 2839, 2894],
#  706: [2633, 2844, 2907, 2906],
#  707: [2828, 2741, 2714, 3037, 2967],
#  708: [2907, 3050, 2983, 2879, 2894, 2904, 2741, 2991],
#  709: [2641, 2967, 2839, 2697, 2909, 3027],
#  710: [3020, 2685, 2973, 2782, 2967, 2962, 2830, 3022, 2903],
#  711: [2963, 2874, 2982, 2869],
#  712: [2918, 3035, 3100, 2813],
#  713: [3020, 2932, 2961, 3006, 2890],
#  714: [3008, 2980, 2973, 2904, 2710, 3042, 2878, 2841, 2830],
#  715: [3035, 2771, 3033, 3020, 2841, 3050],
#  716: [2913, 2777, 2919, 3027],
#  717: [3110, 3100, 2741],
#  718: [2687, 2851, 2852, 2712, 3043, 2639],
#  719: [2869, 2879, 2894, 3031, 2636],
#  720: [3091, 2777, 2919],
#  721: [3041, 3099, 2656, 3006, 2726, 2920, 2809, 2928, 2636],
#  722: [2657, 2698, 3027],
#  723: [2704, 2874, 3083, 2920, 3006],
#  724: [2779, 2977, 2814],
#  725: [2910, 2841, 2976, 2656, 3006],
#  726: [2843, 2783, 2898],
#  727: [2869, 2853, 2992],
#  728: [2956, 3107, 2640, 3024],
#  729: [2999, 2887, 2819],
#  730: [2828, 2741, 2905, 2893],
#  731: [2928, 2888, 2793, 2894, 2656, 3006],
#  732: [3037, 2810, 2874, 3062],
#  733: [2962, 3050, 2959, 3020, 2840, 2697],
#  734: [2967, 2827, 2773, 3031, 2987, 2961, 3006],
#  735: [2641, 2967, 3004, 2741],
#  736: [2767, 2871, 2826],
#  737: [2656, 2962, 2861, 2643, 3006, 3028, 2928, 2718, 2841],
#  738: [3031, 2941, 3090, 2788, 2841, 3050],
#  739: [2938, 2765, 2726, 2829, 2846],
#  740: [3061, 2852, 2817, 3031, 2888, 3095, 2809, 3033, 2928],
#  741: [2739, 3089, 2675],
#  742: [2712, 2857, 2687],
#  743: [2842, 2710, 2903, 2820, 2946, 2909, 2783, 3099],
#  744: [2992, 2964, 3035, 3100, 2731, 2826],
#  745: [2687, 2909, 2899, 2839, 2795, 3022, 3005, 2928, 2853, 2992],
#  746: [2684, 2779, 3024, 3033, 2967, 3006],
#  747: [2785, 2991, 2845, 2843, 2839],
#  748: [2779, 2898, 2868, 3073, 2835, 3006],
#  749: [2785, 2991, 2907, 2861],
#  750: [2633, 2928, 2745, 2649],
#  751: [2641, 2928, 3100, 2677, 2861, 2643, 3006],
#  752: [2739, 3073, 2725, 3090, 2843, 3027],
#  753: [2894, 2918, 2712, 2725],
#  754: [3035, 2879, 2795],
#  755: [3091, 3071, 3070, 3091, 2657, 2698, 2839],
#  756: [2830, 3022, 2776, 2949, 2898],
#  757: [2659, 3044, 2814, 2839, 3072],
#  758: [2913, 2907, 3012, 2907, 3012],
#  759: [3024, 2831, 2969],
#  760: [3084, 3107, 2640, 2898, 3021, 2839],
#  761: [2913, 2907, 3012, 2907, 3012, 3000],
#  762: [2894, 2918, 2712, 2725, 2843, 3027],
#  763: [2699, 2852, 2817, 2949, 2898],
#  764: [2699, 2852, 3021, 2809, 2831],
#  765: [2687, 3014, 2907, 3050, 2698, 2839],
#  766: [2884, 3100, 2677, 3050],
#  767: [2697, 2909, 2899, 2980],
#  768: [3024, 2967, 2808, 3090, 3061],
#  769: [2815, 2991, 2907],
#  770: [3107, 2640, 2898, 2817, 2656, 3006],
#  771: [2683, 2840, 2969],
#  772: [2949, 2876, 2767, 2841, 3073],
#  773: [3095, 2899, 2980],
#  774: [2909, 2783, 2898, 2817],
#  775: [2845, 2680, 2712, 2857, 2971, 2853],
#  776: [2703, 2765, 3028, 2928, 2718, 2841],
#  777: [2999, 2887, 2841, 2988],
#  778: [3091, 3024, 2831, 3091],
#  779: [2695, 3054, 2917, 3033, 2928],
#  780: [2992, 2964, 3021, 2899],
#  781: [2687, 2851, 2718, 2857, 2814],
#  782: [2942, 2729, 2657, 2983, 2636, 3012, 3024],
#  783: [2739, 3012, 2845],
#  784: [2815, 2991, 2907, 2906, 2687, 2909, 2839],
#  785: [2898, 2817, 2772, 2857, 2687, 2851, 3049, 2919],
#  786: [2843, 3022, 2664, 2907],
#  787: [2779, 3000, 2689, 2664, 2898, 2714, 3061, 2636, 2830],
#  788: [3095, 2809, 3038, 2723, 2729, 2907],
#  789: [2971, 2987, 2961, 3006],
#  790: [2991, 2632, 3095],
#  791: [2943, 2977, 2903],
#  792: [3063, 2991, 2632, 2793],
#  793: [2703, 2857, 2687, 2934, 2640, 2907],
#  794: [2904, 2741, 2868, 3073, 2725],
#  795: [2664, 2907, 2644, 2830, 2809, 3033, 3020, 2841, 3073],
#  796: [2842, 2813, 2973, 3031, 2636],
#  797: [3070, 2795, 3027],
#  798: [3063, 2991, 2907, 2752, 3095, 3006, 2945, 2897],
#  799: [2687, 2767, 2857, 2903, 2919, 2962, 2988],
#  800: [2680, 3035, 2653, 2814, 2839, 3072, 2969, 2852],
#  801: [2869, 2675, 2957],
#  802: [2839, 2763, 2680, 3021, 2839, 3072, 2969],
#  803: [2870, 3027, 3060, 2698],
#  804: [2894, 3031, 2636, 2830],
#  805: [2699, 2636, 3036, 3023, 2938, 2840, 2697],
#  806: [2965, 2910, 2840, 2894],
#  807: [2887, 3075, 2774, 2830, 2947],
#  808: [3109, 3035, 2636, 2861, 2787],
#  809: [3063, 3035, 3100, 2813, 3031, 2636, 2988],
#  810: [2842, 2813, 2908, 2687, 2909, 3006],
#  811: [3061, 2888, 2633, 2844, 2907, 3089],
#  812: [2664, 2845, 2756],
#  813: [3100, 2813, 2656, 3006],
#  814: [2961, 3003, 2698, 2980, 2949, 2632, 2633, 2967, 2839],
#  815: [2779, 2789, 2643, 2701, 2765, 2991],
#  816: [3031, 2834, 2779, 3099, 2772, 2747, 3033, 2928, 2879],
#  817: [3089, 2636, 2988, 2894, 2772, 2857, 2903],
#  818: [2859, 2765, 2720],
#  819: [2934, 2677, 3050, 3080, 2898, 2712, 2729, 2907],
#  820: [2763, 2788, 2857, 2734],
#  821: [2992, 3014, 3099],
#  822: [2907, 3089, 2853, 2992, 2909, 3006],
#  823: [3015, 2852, 3021, 2783, 2907],
#  824: [2841, 2976, 2949, 2977, 2776],
#  825: [2689, 2971, 2853, 2908, 2687],
#  826: [2664, 3000, 2697, 2909, 2889, 2686],
#  827: [2969, 2771, 2967],
#  828: [2931, 2907, 3036, 3015],
#  829: [3063, 2991, 2977, 2903, 2919, 3006, 2890],
#  830: [2913, 3000, 2703, 2857],
#  831: [2677, 2752, 2633, 2967, 2855, 2683, 2840, 2697, 2909, 3027],
#  832: [2658, 2898, 2712, 2835, 2980, 2914],
#  833: [2636, 2830, 2839],
#  834: [3000, 3072, 2969, 2852, 2817, 2656, 3027],
#  835: [2969, 2771, 2648],
#  836: [2656, 2956, 3107, 2974, 2747, 2844],
#  837: [3020, 2819, 2779],
#  838: [2992, 2767, 2840],
#  839: [3012, 3040, 2961, 2809],
#  840: [3005, 2928, 2987, 2961, 3006],
#  841: [2992, 3014, 2907],
#  842: [2942, 2729, 2760, 2920, 2980, 2656, 3006],
#  843: [3041, 2642, 3066],
#  844: [3109, 2712, 2835, 3027],
#  845: [3014, 3040, 2961],
#  846: [2788, 2841, 3089, 2853],
#  847: [2694, 3100, 3056, 2633, 2967],
#  848: [2991, 2789, 2942, 2840, 2697],
#  849: [2969, 2852, 2945, 3021, 2809],
#  850: [2894, 2918, 2712, 2841, 3050],
#  851: [2859, 2662, 2651],
#  852: [3061, 3001, 2977, 2687, 2909, 3027],
#  853: [2699, 2745, 2636, 2988],
#  854: [2703, 3075, 2643],
#  855: [2788, 3043, 2672, 2880],
#  856: [3107, 2645, 2839, 2969],
#  857: [2830, 3022, 2903],
#  858: [2763, 2931, 2898, 3101, 2995, 3020, 2841, 3050],
#  859: [2788, 2841, 2906, 2687, 2909, 2839],
#  860: [2680, 3021, 2839, 2795, 3006, 2804, 2961, 2839],
#  861: [2701, 2685, 2992, 2909, 3006],
#  862: [2909, 2783, 2845, 2843, 3027],
#  863: [3076, 2898, 2945, 3035],
#  864: [2927, 2712, 2765, 2991, 2977, 2687, 3014],
#  865: [2949, 2760, 2779, 2898, 2712, 2841, 2861],
#  866: [2991, 2632, 2651, 2859, 2685],
#  867: [2992, 2909, 2855],
#  868: [3049, 3048, 2991],
#  869: [2680, 3021, 2839, 3072, 2795, 3027],
#  870: [2772, 2725, 2756],
#  871: [2779, 3000, 3091, 3024, 2844],
#  872: [2763, 3037, 2844, 3000, 2697],
#  873: [3014, 2939, 2696, 2809, 2993, 2762, 2813],
#  874: [2851, 2718, 2840, 2703, 2841],
#  875: [3063, 2712, 2840, 2763],
#  876: [2697, 3014, 2907, 3036, 2681],
#  877: [2761, 2835, 2980, 2848, 3012, 2760, 2920, 2839, 2795],
#  878: [3091, 3040, 3007, 2679],
#  879: [2699, 2636, 2976, 2656, 3006, 3021, 2947],
#  880: [2852, 2712, 2835, 2962, 2976, 2949, 3024],
#  881: [3061, 2941, 3090, 3067],
#  882: [2946, 2767, 2840, 2999, 2919, 2947],
#  883: [3091, 3071, 3002, 2761, 2871, 2882, 3089, 2636],
#  884: [2843, 2839, 2894, 2782, 2967],
#  885: [3020, 2932, 2961, 3006],
#  886: [3080, 2898, 2991, 2760],
#  887: [2910, 2685, 2992, 2851, 3100, 2813],
#  888: [2894, 2918, 2991, 2953, 2841, 2830, 3027],
#  889: [2680, 3021, 2839, 2795, 3006, 2804, 2961, 3027],
#  890: [3084, 3107, 2640, 2898, 3021],
#  891: [2887, 2765, 2929, 2667],
#  892: [3107, 2974, 2857, 2903],
#  893: [2967, 2855, 2699, 2636, 3050, 2785, 2991, 3000, 3072],
#  894: [2789, 2694, 2888, 2869],
#  895: [2785, 3021, 2783, 3000, 2795],
#  896: [2785, 2991, 2760],
#  897: [2763, 2843, 2783, 2898, 2890],
#  898: [2705, 2953, 2674, 3015, 2636],
#  899: [3031, 3001, 3000, 2894],
#  900: [3052, 2660, 2852, 2720, 2803, 2938, 2840, 2697],
#  901: [3020, 2932, 2961],
#  902: [2971, 2718, 2841, 2976, 2918, 3021, 2783, 3071],
#  903: [2697, 3014, 2789],
#  904: [2833, 2809, 3033, 2846],
#  905: [2697, 2851, 2941, 2756],
#  906: [2815, 2712, 2840, 2999, 2919, 2980],
#  907: [2992, 2767, 2857, 2903, 2995, 2846],
#  908: [2828, 2989, 2663],
#  909: [2843, 3006, 2868, 3089, 2649],
#  910: [2779, 3024, 2648, 2694, 2636],
#  911: [2922, 2741, 3028, 2846],
#  912: [2887, 2765, 2890, 2689, 2687],
#  913: [2971, 3100, 2749, 3037, 2967],
#  914: [2701, 2871, 2826, 3039, 2992, 2800],
#  915: [2687, 3014, 2907, 2976, 2656, 3006, 3021, 2809, 3033, 2967, 2839],
#  916: [2894, 2949, 2898, 2937, 2687],
#  917: [3011, 3070, 2703, 2747, 3033, 3020],
#  918: [3109, 3021, 2839, 2689, 2971],
#  919: [3004, 2741, 3035, 2941, 2843, 2783, 2907],
#  920: [2961, 3006, 2726, 2683, 2857, 2814, 2809, 3033, 3020],
#  921: [2643, 3006, 2712, 2662, 2651, 3095, 3027],
#  922: [2904, 2741, 2929, 2859, 2841, 3012, 2789, 2694],
#  923: [3091, 3024, 2844, 3099, 2949],
#  924: [2815, 3021, 2783, 2789, 2688, 3063, 2744, 2874, 2982, 2793],
#  925: [2779, 2898, 2991, 3000, 2689, 2687, 2767, 2841, 3089],
#  926: [2683, 2747, 3033],
#  927: [2779, 3099, 2908, 2687, 2800, 2894, 2772, 2857, 2903, 2681],
#  928: [2959, 2810, 2813, 2656, 2962],
#  929: [3020, 2950, 3107, 3016, 2852],
#  930: [3110, 2771, 3033, 2928, 2675, 2686],
#  931: [2843, 3006, 2890, 2703, 2729, 2907],
#  932: [2870, 2701, 2871, 2826, 2767, 2841, 3050],
#  933: [3035, 2771, 3033, 2831],
#  934: [2920, 2947, 2713, 3006],
#  935: [2971, 2771, 3033, 2844, 2898, 2720],
#  936: [2962, 2892, 2961, 2809, 2928, 2941, 2843],
#  937: [3005, 2810, 3056],
#  938: [3045, 2655, 2663, 2938, 2765],
#  939: [2664, 3024, 2862, 2658, 2789, 2694, 2879],
#  940: [3091, 3040, 3007, 2852, 2897],
#  941: [2842, 2813, 2973],
#  942: [2977, 2971, 2852, 2868],
#  943: [3041, 2898, 2726, 2920, 3027],
#  944: [2969, 2888, 2913],
#  945: [3110, 2636, 2976, 2772, 2841, 3012],
#  946: [2643, 2809, 3020, 2857, 2878, 2951, 3100, 3070],
#  947: [3031, 2966, 2698, 2980, 2992, 2909, 3006],
#  948: [2971, 2853, 2973, 2949, 2657, 2698],
#  949: [3045, 3024, 2844, 2760, 2779, 3099, 2949],
#  950: [3021, 2855, 2699, 2987, 2961],
#  951: [2715, 3073, 2883, 3008],
#  952: [2963, 3070, 2894],
#  953: [2869, 3100, 2974, 2747, 3033, 2928, 2636],
#  954: [2779, 2977, 2664, 2898, 3035, 2636, 3073],
#  955: [2949, 2760, 2779, 2898, 2712],
#  956: [2962, 2861, 2942, 2932, 2961, 2839],
#  957: [2795, 3022, 2776, 2772, 2951, 2636, 2988],
#  958: [2949, 2953, 2747],
#  959: [3076, 2898, 2738, 3076, 3024, 3033, 2967],
#  960: [3057, 2857, 2664, 2760, 2779],
#  961: [2815, 2991, 2907, 2861],
#  962: [3021, 2839, 2795, 3006, 2804, 2961],
#  963: [2971, 3001, 3099, 2772, 2841, 3050],
#  964: [2839, 2689, 2664, 2898, 3035, 2771, 2967],
#  965: [2643, 2855, 2920, 3006, 2991, 2898, 2991],
#  966: [3014, 2907, 2861, 2803, 3011, 3017, 2831],
#  967: [2969, 3100, 2741, 2720, 2694, 3100, 2731, 2826],
#  968: [2795, 2855, 2699, 2771, 3020, 2841, 3012],
#  969: [3035, 2745, 2853, 2998],
#  970: [2641, 2844, 2907, 3036],
#  971: [2869, 2879, 2689],
#  972: [2841, 2644, 2830, 3006],
#  973: [2683, 3075, 3051, 3092, 2967],
#  974: [2852, 2722, 2639],
#  975: [2669, 2658, 2845, 3061, 2852, 2991, 3099, 2656, 3027],
#  976: [2922, 2741, 2945, 2991, 2907, 2976],
#  977: [3061, 2852, 2817, 2772, 2951, 2636, 2988],
#  978: [2971, 2636, 2906, 2814, 2962, 2976, 2918, 2991, 3099, 2656],
#  979: [3102, 2813, 2908, 2687],
#  980: [2920, 2783, 3099, 2914],
#  981: [2785, 2991, 2876, 3014, 2760],
#  982: [2779, 2898, 2712, 2841, 3012, 2898, 2991],
#  983: [2969, 2771, 3020, 3075],
#  984: [2971, 2745, 3049, 2887, 2835, 2839],
#  985: [2963, 2974, 2857, 2814, 3027],
#  986: [2788, 2841, 2976, 3031],
#  987: [2920, 2855, 2982, 2815, 2991, 2907, 2830, 2839],
#  988: [2969, 3100, 2749],
#  989: [2762, 3016, 2653],
#  990: [3012, 2845, 2931],
#  991: [2815, 2712, 2951, 2653, 2687, 2909],
#  992: [2641, 2967, 2839, 2697],
#  993: [2843, 2783, 2977, 2687],
#  994: [2761, 3075, 2705, 3024, 3020, 2729],
#  995: [2689, 2664, 3024, 2967, 3027],
#  996: [2934, 3070, 2999, 2919, 3027],
#  997: [2857, 2814, 3059, 3095, 3006, 2886],
#  998: [3014, 2632, 2913, 2907, 2830, 3006, 3035],
#  999: [2842, 2813, 2973, 2656, 3006, 2738, 2641, 3020, 2835, 3027],
#  ...}

# %%
class FastTextVanilla:
    def __init__(self, vocabulary, ngramm2id, token2subwords, emb_size, window_size, ns_rate, pad_idx=0):
        self.vocabulary = vocabulary
        self.vocab_size = len(vocabulary)
        
        self.ngramm2id = ngramm2id
        self.ngramm_size = len(ngramm2id)
        
        self.token2subwords = token2subwords
        
        self.emb_size = emb_size
        self.window_size = window_size
        self.ns_rate = ns_rate
        self.pad_idx = pad_idx
        
        self.center_embeddings = np.random.uniform(-1.0/self.emb_size, 1.0/self.emb_size,
                                                   size=(self.vocab_size+self.ngramm_size, self.emb_size))
        self.center_embeddings[pad_idx] = 0
        
        self.context_embeddings = np.random.uniform(-1.0/self.emb_size, 1.0/self.emb_size,
                                                    size=(self.vocab_size, self.emb_size))
        self.context_embeddings[pad_idx] = 0
        
        self.id2word = {i: w for w, i in self.vocabulary.items()}
        
        self.embeddings_normed = None
        
    
    def norm_embeddings(self):
        self.embeddings_normed = self.center_embeddings / (np.linalg.norm(
            self.center_embeddings, ord=2, axis=-1, keepdims=True) + 1e-4)

    def generate_ft_sgns_samples(self, text):
        """
        text - list of integer numbers - ids of tokens in text
        window_size - odd integer - width of window
        vocab_size - positive integer - number of tokens in vocabulary
        ns_rate - positive integer - number of negative tokens to sample per one positive sample
        token2subwords - list of lists of int - i-th sublist contains list of identifiers of n-grams for token #i (list of subword units)

        returns list of training samples (CenterSubwords, CtxWord, Label)
        """
        text = np.array(text)
        size = len(text)
        context_words_idxs = make_diag_mask(size, self.window_size)
        center_words_idx = np.eye(N=size, dtype=int)

        result = []

        for i, word in enumerate(text):
            context = context_words_idxs[i]
            center = center_words_idx[i]

            context_idx = np.where(context != 0)[0]
            center_idx = np.where(center != 0)[0]

            center_word = text[center_idx].tolist()
            context_words = text[context_idx]

            center_word.extend(self.token2subwords[word])

            positive_examples = [tuple(list(j) + [1]) for j in product([center_word], context_words)]
            positive_examples = [
                positive_example for positive_example in positive_examples if self.pad_idx not in positive_example
            ]

            # чтобы не совпадало с самим собой
            all_words = np.arange(self.vocab_size)
            center_word_idx = np.argwhere(all_words == text[center_idx].tolist())[0][0]
            all_words = list(all_words)
            del all_words[center_word_idx], all_words[self.pad_idx]
            all_words = np.array(all_words)
            negative_word = np.random.choice(all_words)

            # выбрать одно из двух, либо убрать совпадение с самим собой, либо нет
            negative_words = np.random.randint(self.vocab_size, size=self.ns_rate*len(positive_examples))    
            negative_examples = [tuple(list(j) + [0]) for j in product([center_word], negative_words)]

            positive_negative_examples = positive_examples + negative_examples
            result.extend(positive_negative_examples)

        return result
    
    def update_ft_weights(self, center_subwords, context_word, label, learning_rate):
        """
        center_embeddings - VocabSize x EmbSize
        context_embeddings - VocabSize x EmbSize
        center_subwords - list of ints - list of identifiers of n-grams contained in center word
        context_word - int - identifier of context word
        label - 1 if context_word is real, 0 if it is negative
        learning_rate - float > 0 - size of gradient step
        """
        # Выберем центральное и контекстное слово
        center_embedding = self.center_embeddings[center_subwords]
        context_embedding = self.context_embeddings[[context_word]]

        # Считаем "оценку" сходства и ее вероятность по формуле
        # 𝑃(𝐶𝑡𝑥𝑊𝑜𝑟𝑑|𝐶𝑒𝑛𝑡𝑒𝑟𝑆𝑢𝑏𝑤𝑜𝑟𝑑𝑠)=𝜎((∑𝑙𝑒𝑛(𝐶𝑒𝑛𝑡𝑒𝑟𝑆𝑢𝑏𝑤𝑜𝑟𝑑𝑠)𝑤∈𝐶𝑒𝑛𝑡𝑒𝑟𝑆𝑢𝑏𝑤𝑜𝑟𝑑𝑠𝑊𝑤,:𝑙𝑒𝑛(𝐶𝑒𝑛𝑡𝑒𝑟𝑆𝑢𝑏𝑤𝑜𝑟𝑑𝑠))⋅𝐷𝐶𝑡𝑥𝑊𝑜𝑟𝑑,:)
        score = np.mean(center_embedding, axis=0, keepdims=True).dot(context_embedding.T)
        prob = sigmoid(score)
        loss = log_loss(label, prob)

        # Считаем производные для правила цепочки: производная лосса * производную сигмоиды
        # * производную 𝑊𝐶𝑒𝑛𝑡𝑒𝑟𝑊𝑜𝑟𝑑,:⋅𝐷𝐶𝑡𝑥𝑊𝑜𝑟𝑑,: по 𝑊𝐶𝑒𝑛𝑡𝑒𝑟𝑊𝑜𝑟𝑑 и 𝐷𝐶𝑡𝑥𝑊𝑜𝑟𝑑
        log_loss_deriv = log_loss_derivative(np.array([label]), np.array(prob))
        sigmoid_deriv = sigmoid_derivative(score)

        # Считаем производные по цетральному слову и контекстному для обновления весов
        center_grad = log_loss_deriv * sigmoid_deriv * context_embedding / len(center_subwords)
        context_grad = log_loss_deriv * sigmoid_deriv * np.mean(center_embedding, axis=0, keepdims=True)

        self.center_embeddings[center_subwords] -= learning_rate * center_grad
        self.context_embeddings[[context_word]] -= learning_rate * context_grad

        return loss

    
    def fit(self, dataset, learning_rate=1e-2, n_epochs=10):
        for n in tqdm(range(n_epochs)):
            try:
                idxs = np.random.permutation(len(dataset))

                for i, idx in enumerate(idxs):
                    data = dataset[idx]
                    samples = self.generate_ft_sgns_samples(text=data)

                    cur_idx = 1
                    cur_loss = 0

                    for sample in samples:
                        center_subwords, context_word, label = sample

                        loss = self.update_ft_weights(
                            center_subwords=center_subwords,
                            context_word=context_word,
                            label=label,
                            learning_rate=learning_rate
                        )

                        cur_loss += loss
                        cur_idx += 1

                print(f"LOSS: {cur_loss / cur_idx}")

            except KeyboardInterrupt:
                print('Досрочно остановлено пользователем')
                return self

            except Exception as ex:
                print('Ошибка при обучении: {}\n{}'.format(ex, traceback.format_exc()))
                break
        return self
    
    def most_similar(self, word, topk=10):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        return self.most_similar_by_vector(self.get_vector(word), topk=topk)

    def analogy(self, a1, b1, a2, topk=10):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        a1_v = self.get_vector(a1)
        b1_v = self.get_vector(b1)
        a2_v = self.get_vector(a2)
        query = b1_v - a1_v + a2_v
        return self.most_similar_by_vector(query, topk=topk)

    def most_similar_by_vector(self, query_vector, topk=10):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        similarities = (self.embeddings_normed[:self.vocab_size] * query_vector).sum(-1)
        best_indices = np.argpartition(-similarities, topk, axis=0)[:topk]
        result = [(self.id2word[i], similarities[i]) for i in best_indices]
        result.sort(key=lambda pair: -pair[1])
        return result

    def get_vector(self, word):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        if word not in self.vocabulary:
            raise ValueError('Неизвестное слово "{}"'.format(word))
        return self.embeddings_normed[self.vocabulary[word]]

    def get_vectors(self, *words):
        assert self.embeddings_normed is not None, 'Необходимо нормировать эмбеддинги self.norm_embeddings'
        word_ids = [self.vocabulary[i] for i in words]
        vectors = np.stack([self.embeddings_normed[i] for i in word_ids], axis=0)
        return vectors

# %%
fasttext = FastTextVanilla(
    vocabulary=word2id,
    ngramm2id=ngramm2id,
    token2subwords=token2subwords,
    emb_size=100,
    window_size=5,
    ns_rate=10,
    pad_idx=0
)

# %%
fasttext.fit(dataset, n_epochs=3)
# Out:
#  33%|███████████████████████████▎                                                      | 1/3 [27:32<55:05, 1652.93s/it]
# LOSS: 0.1542979294302138
#  67%|██████████████████████████████████████████████████████▋                           | 2/3 [55:11<27:36, 1656.17s/it]
# LOSS: 0.0
# 100%|████████████████████████████████████████████████████████████████████████████████| 3/3 [1:22:38<00:00, 1652.99s/it]
# LOSS: 0.22443739081415162

# %%
fasttext.norm_embeddings()
print('chicken\n', fasttext.most_similar('chicken'), '\n')
print('wine\n', fasttext.most_similar('wine'), '\n')
print('salt\n', fasttext.most_similar('salt'), '\n')
# Out:
# chicken
#  [('chicken', 0.9999438705060457), ('broth', 0.8522845357240816), ('stock', 0.8264915899448626), ('homemade', 0.8163790970614407), ('fish', 0.789068851834661), ('sodium', 0.7542037407875364), ('quarts', 0.7486070354691838), ('skinless', 0.7427085342574133), ('beef', 0.7375763240696203), ('vegetable', 0.7254080895618105)]
#
# wine
#  [('wine', 0.9999497635735426), ('sherry', 0.8516056872629647), ('champagne', 0.8140638736784306), ('vinegar', 0.7976674277249974), ('ruby', 0.7823168028606087), ('shaoxing', 0.7780367584946614), ('cider', 0.7679885671184234), ('shao', 0.7415824977598999), ('cognac', 0.7305820144955263), ('full', 0.7167917985935811)]
#
# salt
#  [('salt', 0.9999687565909968), ('black', 0.8621077213765054), ('taste', 0.8393914102384562), ('tomatoes', 0.8266827619283045), ('brisket', 0.8257603749587378), ('pepper', 0.8181771661170533), ('bell', 0.8020285316227762), ('cayenne', 0.8006072539935507), ('nblack', 0.7966581208768948), ('dozen', 0.7947899873440986)]

# %%
from IPython.display import HTML

with open('./style.css') as f:
    style = f.read()
HTML(style)
# Out:
# <style>
#
# div #notebook {
#     background-color: #FFF9EE;
#     margin: auto;
# }
#
# #notebook-container {
#     padding: 15px;
#     background-color: #FFFAFA;
#     min-height: 0;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.2);
#     box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.2);
# }
#
# div.cell { /* set cell width to about 80 chars */
#     background-color: #FFFAFA;
# }
#
# div.cell.border-box-sizing.code_cell.running {
#     border: 3px solid #111;
# }
#
# div.cell.code_cell {
#     background-color: #FFFAFA ;
#     border-radius: 5px;
#     padding: 1em;
#     margin-top: 1em;
# }
#
# div.text_cell_render{
#     font-family: 'Times New Roman';
#     color: #B8860B
# }
#
# .text_cell_render h1 {
#     font-family: 'Times New Roman';
#     font-weight: 300;
#     font-size: 40pt;
#     line-height: 100%;
#     color: #8B4513;
#     font-style: italic;
# }
#
# .text_cell_render h2 {
#     font-family: 'Times New Roman';
#     font-weight: 700;
#     font-size: 30pt;
#     line-height: 100%;
#     color: #8B4513;
#     font-style: italic;
# }
#
# .text_cell_render h3 {
#     font-family: 'Times New Roman';
#     font-size: 25pt;
#     margin-bottom: 3px;
#     font-style: italic;
#     color: #8B4513;
# }
#
# .text_cell_render h4 {
#     font-family: 'Times New Roman';
#     font-size: 20pt;
#     color: #8B4513;
#     font-style: italic;
# }
#
# .text_cell_render h5 {
#     font-family: 'Times New Roman';
#     font-weight: 300;
#     font-size: 16pt;
#     color: #8B4513;
#     font-style: italic;
# }
#
# .text_cell_render h6 {
#     font-family: 'Times New Roman';
#     font-weight: 300;
#     font-size: 10pt;
#     color: #8B4513;
#     font-style: italic;
# }
#
# .text_cell_render p {
#     font-family: 'Times New Roman';
#     font-size: 15pt;
#     color: black;
#     text-align: justify;
#     text-justify: inter-word;
#     line-height: 1.5;
# }
#
# mark {
#   background: #D5EAFF;
#   color: black;
# }
#
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:2000px;  /* your desired max-height here */
# }
#
# .CodeMirror{
#     background-color: #FFFAFA;
# }
# </style>
